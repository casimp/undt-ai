# %% [markdown]
# # CNN Depth Measurements - Comparison with 'Standard' Techniques
# ---
# Chris Simpson

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l1
from tensorflow.keras.callbacks import TensorBoard

from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPool1D, Dropout, Flatten, BatchNormalization, Activation
from tensorflow.keras.models import Model
from pathlib import Path

# Helper libraries
import seaborn as sns
import time
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.signal import hilbert

from undt_ai.load import load_pipeline, load_single
from undt_ai.tools import rmse, normal
from undt_ai.synthetic_build import n_layer_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, CSVLogger
#sns.set(style="ticks")

print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-77b9e9bbc3e8> in <module>
#      19 from scipy.signal import hilbert
#      20
# ---> 21 from undt_ai.load import load_pipeline, load_single
#      22 from undt_ai.tools import rmse, normal
#      23 from undt_ai.synthetic_build import n_layer_model
#
# ModuleNotFoundError: No module named 'undt_ai'

# %% [markdown]
# ## Locate Data Files and Load
# ---

# %%
fpath_s = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/synth_data.npz')
fpath_sf = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/synth_flat.npz')
out_dir = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/')

# %%
data = load_pipeline(fpath_s, levels =[0])
t,data = data[:3], data[3:]
t = t[0][0]

x_train, x_val, x_test = data[:3]
Dmin_train, Dmin_val, Dmin_test = data[3:6]
D_train, D_val, D_test = data[6:9]
rms_train, rms_val, rms_test = data[9:]

y_train, y_val, y_test = D_train, D_val, D_test

# %%
print(t.shape)
# Out:
# (255, 1)

# %% [markdown]
# ## Data Overview
# ---

# %%
#tb, _, _, _, _ = load_single_wtime(fpath_sf, crop=0)
tb, xb, _, _, _ = load_single(fpath_s, crop=0)

select=192
plt.plot(tb[0], xb[select])

# %%
from mpl_toolkits.axes_grid1 import ImageGrid

fig = plt.figure(figsize=(12, 4.))

axarr = ImageGrid(fig, 111,          # as in plt.subplot(111)
                 nrows_ncols=(1,3),
                 axes_pad=0.15,
                 share_all=True,
                 cbar_location="right",
                 cbar_mode="single",
                 cbar_size="7%",
                 cbar_pad=0.15,
                 )

root_path = Path.home() / 'Google Drive/1851traceData/'

for i, (f, letter, sig, lambd) in enumerate(zip(['run33/corrosionMapIteration361.npy', 
                                  'run38/corrosionMapIteration491.npy',
                                   'run39/corrosionMapIteration49.npy'], ['(a)', '(b)', '(c)'],
                                 [0.14, 0.52, 0.60], [1.0, 1.0, 0.5])):
    mp = np.load(root_path / f)
    corr_map = axarr[i].contourf(np.arange(0,77) * 0.25, np.arange(0,77) * 0.25, 1000 * mp, 
                                 cmap='viridis', levels=np.linspace(-2.,2., 11))
    txt = f'{letter} ' + r'$\sigma=$' + f'{sig:.2f}, ' + r'$\lambda=$' + f'{lambd:.1f}'
    axarr[i].text(s=txt, x=1.5, y=17., bbox=dict(facecolor='w', edgecolor='k', pad=5.0))
    axarr[i].set_xlabel('x (mm)')
    axarr[i].plot(np.array([7, 7, 13, 13, 7]) - 0.5, np.array([7, 13, 13, 7, 7]) - 0.5, ls='--', c='0.1')
    
##cbar = plt.colorbar(corr_map)

axarr[0].set_ylabel('y (mm)')
clab = axarr[-1].cax.colorbar(corr_map)
axarr[-1].cax.toggle_label(True)
clab.set_label_text('z (mm)')
#fig.colorbar(corr_map, ax=axarr.ravel().tolist())

#fig.tight_layout()
#plt.axis('equal')

figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
fig.savefig(figpath / 'params_dist_map_ap.png', dpi=400)

# %%
g = sns.jointplot(1e3*D_train, 1e3*Dmin_train, s=4, alpha=0.1, color='k').set_axis_labels("$D$ (mm)", "$D_{min}$ (mm)")
g.ax_joint.plot([6, 15], [6, 15], 'k-', lw=1, label='$D_{min} = D$')  
g.ax_joint.text(5.5, 14.5, '(a)', size=14)
g.ax_joint.legend(loc=4)

plt.tight_layout()
figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
plt.savefig(figpath / 'params_dist_D.png', dpi=400)

# %%
g = sns.jointplot(1e3*D_train, 1e3*rms_train, s=4, alpha=0.15, color='k').set_axis_labels("$D$ (mm)", "$\sigma$ (mm)")
#g.ax_joint.plot([6, 15], [6, 15], 'k-', lw=1, label='$D_{min} = D$')  
g.ax_joint.text(5.5, 1.125, '(b)', size=14)
plt.tight_layout()
figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
plt.savefig(figpath / 'params_dist_rms.png', dpi=400)

# %% [markdown]
# # Measured Dmin and Dmean: CNN w/ Linear Regression
# Use a regression activation function (loss function = MSE) on the final layer to predict a continuous value for thickness. Use the full (downsampled) data.
#
# ### Model Setup
# ---
# - 2 Conv Layers w/ Pooling and Dropout on FCN
# - Split off 20% of the data to test the model
# - We'll also use a validation/development training set of a similar size (for TensorBoard!)

# %% [markdown]
# # CNN Architecture: Create and Save 3 Layer CNN

# %%
model = n_layer_model(n_layers=3, filters=64, kernel_size=71, 
                        drop_layers=[-1], drop_fraction=0.2, pool_step=0, batch_norm=True)
model.summary()

ipath = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/D_3L_71K_BN_D0p2_initial.h5')
model.save(ipath)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 255, 1)]          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 185, 64)           4608
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 185, 64)           256
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 115, 64)           290880
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 115, 64)           256
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 45, 64)            290880
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 45, 64)            256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 45, 64)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2880)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2881
# =================================================================
# Total params: 590,017
# Trainable params: 589,633
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# # CNN - $D_{mean}$
#
# Load the saved initial model - key point is to reload the custom metric

# %%
model_D = tf.keras.models.load_model(ipath, custom_objects={'rmse': rmse})

# %%
spath = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/D_3L_71K_BN_D0p2.h5')

#reduce_lr = ReduceLROnPlateau(patience=50, min_delta=0, factor=0.5, monitor='val_loss')
model_checkpoint = ModelCheckpoint(filepath=spath.as_posix(), monitor='val_loss',
                                   save_best_only=True)
model_D.fit(normal(x_train), [1000 * D_train], 
            epochs=600, batch_size=128, 
            validation_data=[normal(x_val), 1e3*y_val], callbacks=[model_checkpoint,])
# Out:
# Train on 8379 samples, validate on 932 samples
# Epoch 1/600
# 8379/8379 [==============================] - 2s 237us/sample - loss: 8.4238 - rmse: 2.2075 - val_loss: 0.7199 - val_rmse: 0.8586
# Epoch 2/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 1.4519 - rmse: 1.1840 - val_loss: 0.6467 - val_rmse: 0.8083
# Epoch 3/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 1.1431 - rmse: 1.0536 - val_loss: 0.3768 - val_rmse: 0.6212
# Epoch 4/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 1.0100 - rmse: 0.9944 - val_loss: 0.2338 - val_rmse: 0.4853
# Epoch 5/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.8519 - rmse: 0.9169 - val_loss: 0.2584 - val_rmse: 0.5061
# Epoch 6/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.6841 - rmse: 0.8185 - val_loss: 0.1853 - val_rmse: 0.4269
# Epoch 7/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.6088 - rmse: 0.7753 - val_loss: 0.2849 - val_rmse: 0.5384
# Epoch 8/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.5198 - rmse: 0.7144 - val_loss: 0.1843 - val_rmse: 0.4301
# Epoch 9/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.4476 - rmse: 0.6645 - val_loss: 0.3255 - val_rmse: 0.5759
# Epoch 10/600
# 8379/8379 [==============================] - 1s 91us/sample - loss: 0.4220 - rmse: 0.6410 - val_loss: 0.1491 - val_rmse: 0.3805
# Epoch 11/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.3637 - rmse: 0.6002 - val_loss: 0.1261 - val_rmse: 0.3540
# Epoch 12/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.3131 - rmse: 0.5575 - val_loss: 0.1290 - val_rmse: 0.3593
# Epoch 13/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.2827 - rmse: 0.5288 - val_loss: 0.1482 - val_rmse: 0.3852
# Epoch 14/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.2917 - rmse: 0.5350 - val_loss: 0.1060 - val_rmse: 0.3307
# Epoch 15/600
# 8379/8379 [==============================] - 1s 91us/sample - loss: 0.2409 - rmse: 0.4887 - val_loss: 0.0847 - val_rmse: 0.2940
# Epoch 16/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.2305 - rmse: 0.4775 - val_loss: 0.1048 - val_rmse: 0.3289
# Epoch 17/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.1980 - rmse: 0.4424 - val_loss: 0.0705 - val_rmse: 0.2695
# Epoch 18/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.1845 - rmse: 0.4270 - val_loss: 0.1274 - val_rmse: 0.3577
# Epoch 19/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.1845 - rmse: 0.4274 - val_loss: 0.1054 - val_rmse: 0.3265
# Epoch 20/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.1622 - rmse: 0.3995 - val_loss: 0.0778 - val_rmse: 0.2738
# Epoch 21/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.1481 - rmse: 0.3825 - val_loss: 0.0577 - val_rmse: 0.2378
# Epoch 22/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1340 - rmse: 0.3642 - val_loss: 0.1268 - val_rmse: 0.3534
# Epoch 23/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1554 - rmse: 0.3892 - val_loss: 0.0797 - val_rmse: 0.2747
# Epoch 24/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1463 - rmse: 0.3794 - val_loss: 0.0680 - val_rmse: 0.2567
# Epoch 25/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1364 - rmse: 0.3657 - val_loss: 0.0843 - val_rmse: 0.2857
# Epoch 26/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1313 - rmse: 0.3587 - val_loss: 0.0612 - val_rmse: 0.2464
# Epoch 27/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.1218 - rmse: 0.3466 - val_loss: 0.0629 - val_rmse: 0.2473
# Epoch 28/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.1271 - rmse: 0.3522 - val_loss: 0.0727 - val_rmse: 0.2739
# Epoch 29/600
# 8379/8379 [==============================] - 1s 93us/sample - loss: 0.1132 - rmse: 0.3346 - val_loss: 0.0434 - val_rmse: 0.2087
# Epoch 30/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.1037 - rmse: 0.3203 - val_loss: 0.0586 - val_rmse: 0.2443
# Epoch 31/600
# 8379/8379 [==============================] - 1s 82us/sample - loss: 0.1092 - rmse: 0.3272 - val_loss: 0.0497 - val_rmse: 0.2252
# Epoch 32/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.1230 - rmse: 0.3471 - val_loss: 0.0696 - val_rmse: 0.2574
# Epoch 33/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.1065 - rmse: 0.3243 - val_loss: 0.1239 - val_rmse: 0.3492
# Epoch 34/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0982 - rmse: 0.3093 - val_loss: 0.0440 - val_rmse: 0.2107
# Epoch 35/600
# 8379/8379 [==============================] - 1s 82us/sample - loss: 0.1055 - rmse: 0.3203 - val_loss: 0.0748 - val_rmse: 0.2740
# Epoch 36/600
# 8379/8379 [==============================] - 1s 81us/sample - loss: 0.0871 - rmse: 0.2931 - val_loss: 0.0484 - val_rmse: 0.2196
# Epoch 37/600
# 8379/8379 [==============================] - 1s 82us/sample - loss: 0.0858 - rmse: 0.2906 - val_loss: 0.0451 - val_rmse: 0.2110
# Epoch 38/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0867 - rmse: 0.2911 - val_loss: 0.0397 - val_rmse: 0.1974
# Epoch 39/600
# 8379/8379 [==============================] - 1s 83us/sample - loss: 0.0851 - rmse: 0.2900 - val_loss: 0.0458 - val_rmse: 0.2086
# Epoch 40/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0929 - rmse: 0.3010 - val_loss: 0.0395 - val_rmse: 0.1945
# Epoch 41/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0818 - rmse: 0.2839 - val_loss: 0.0391 - val_rmse: 0.1950
# Epoch 42/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0953 - rmse: 0.3046 - val_loss: 0.0526 - val_rmse: 0.2213
# Epoch 43/600
# 8379/8379 [==============================] - 1s 81us/sample - loss: 0.0889 - rmse: 0.2955 - val_loss: 0.0506 - val_rmse: 0.2242
# Epoch 44/600
# 8379/8379 [==============================] - 1s 80us/sample - loss: 0.0885 - rmse: 0.2936 - val_loss: 0.0609 - val_rmse: 0.2423
# Epoch 45/600
# 8379/8379 [==============================] - 1s 82us/sample - loss: 0.0952 - rmse: 0.3050 - val_loss: 0.0420 - val_rmse: 0.2032
# Epoch 46/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0782 - rmse: 0.2769 - val_loss: 0.0329 - val_rmse: 0.1804
# Epoch 47/600
# 8379/8379 [==============================] - 1s 82us/sample - loss: 0.0713 - rmse: 0.2642 - val_loss: 0.0464 - val_rmse: 0.2134
# Epoch 48/600
# 8379/8379 [==============================] - 1s 82us/sample - loss: 0.0825 - rmse: 0.2855 - val_loss: 0.0942 - val_rmse: 0.3039
# Epoch 49/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0757 - rmse: 0.2718 - val_loss: 0.0311 - val_rmse: 0.1745
# Epoch 50/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0783 - rmse: 0.2773 - val_loss: 0.1044 - val_rmse: 0.3219
# Epoch 51/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0825 - rmse: 0.2838 - val_loss: 0.0350 - val_rmse: 0.1872
# Epoch 52/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0743 - rmse: 0.2693 - val_loss: 0.0824 - val_rmse: 0.2846
# Epoch 53/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0803 - rmse: 0.2791 - val_loss: 0.0367 - val_rmse: 0.1930
# Epoch 54/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0629 - rmse: 0.2497 - val_loss: 0.0683 - val_rmse: 0.2597
# Epoch 55/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0807 - rmse: 0.2807 - val_loss: 0.1076 - val_rmse: 0.3283
# Epoch 56/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0740 - rmse: 0.2692 - val_loss: 0.0347 - val_rmse: 0.1843
# Epoch 57/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0747 - rmse: 0.2708 - val_loss: 0.0762 - val_rmse: 0.2796
# Epoch 58/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0794 - rmse: 0.2787 - val_loss: 0.0328 - val_rmse: 0.1794
# Epoch 59/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0629 - rmse: 0.2496 - val_loss: 0.0359 - val_rmse: 0.1880
# Epoch 60/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0752 - rmse: 0.2714 - val_loss: 0.0532 - val_rmse: 0.2292
# Epoch 61/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0957 - rmse: 0.3023 - val_loss: 0.0469 - val_rmse: 0.2132
# Epoch 62/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0835 - rmse: 0.2852 - val_loss: 0.0451 - val_rmse: 0.2060
# Epoch 63/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0751 - rmse: 0.2711 - val_loss: 0.0819 - val_rmse: 0.2845
# Epoch 64/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0759 - rmse: 0.2733 - val_loss: 0.0515 - val_rmse: 0.2276
# Epoch 65/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0843 - rmse: 0.2850 - val_loss: 0.0443 - val_rmse: 0.2084
# Epoch 66/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0688 - rmse: 0.2608 - val_loss: 0.0397 - val_rmse: 0.2003
# Epoch 67/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0833 - rmse: 0.2861 - val_loss: 0.0332 - val_rmse: 0.1806
# Epoch 68/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0630 - rmse: 0.2490 - val_loss: 0.0546 - val_rmse: 0.2320
# Epoch 69/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0600 - rmse: 0.2439 - val_loss: 0.0377 - val_rmse: 0.1893
# Epoch 70/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0767 - rmse: 0.2739 - val_loss: 0.0496 - val_rmse: 0.2216
# Epoch 71/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0713 - rmse: 0.2654 - val_loss: 0.0473 - val_rmse: 0.2167
# Epoch 72/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0700 - rmse: 0.2613 - val_loss: 0.0423 - val_rmse: 0.2034
# Epoch 73/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0690 - rmse: 0.2592 - val_loss: 0.0401 - val_rmse: 0.1975
# Epoch 74/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0936 - rmse: 0.2992 - val_loss: 0.1203 - val_rmse: 0.3468
# Epoch 75/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0937 - rmse: 0.2997 - val_loss: 0.0828 - val_rmse: 0.2935
# Epoch 76/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0798 - rmse: 0.2786 - val_loss: 0.0417 - val_rmse: 0.2017
# Epoch 77/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1092 - rmse: 0.3213 - val_loss: 0.0506 - val_rmse: 0.2263
# Epoch 78/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1021 - rmse: 0.3140 - val_loss: 0.0412 - val_rmse: 0.2030
# Epoch 79/600
# 8379/8379 [==============================] - 1s 83us/sample - loss: 0.0804 - rmse: 0.2789 - val_loss: 0.0479 - val_rmse: 0.2159
# Epoch 80/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0708 - rmse: 0.2635 - val_loss: 0.0361 - val_rmse: 0.1837
# Epoch 81/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0597 - rmse: 0.2431 - val_loss: 0.0480 - val_rmse: 0.2205
# Epoch 82/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.1048 - rmse: 0.3138 - val_loss: 0.0315 - val_rmse: 0.1744
# Epoch 83/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0759 - rmse: 0.2730 - val_loss: 0.0816 - val_rmse: 0.2864
# Epoch 84/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0722 - rmse: 0.2662 - val_loss: 0.0444 - val_rmse: 0.2063
# Epoch 85/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0585 - rmse: 0.2392 - val_loss: 0.0352 - val_rmse: 0.1875
# Epoch 86/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0645 - rmse: 0.2512 - val_loss: 0.0685 - val_rmse: 0.2587
# Epoch 87/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0706 - rmse: 0.2618 - val_loss: 0.0292 - val_rmse: 0.1714
# Epoch 88/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0898 - rmse: 0.2938 - val_loss: 0.0414 - val_rmse: 0.2018
# Epoch 89/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0713 - rmse: 0.2650 - val_loss: 0.0662 - val_rmse: 0.2609
# Epoch 90/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0805 - rmse: 0.2781 - val_loss: 0.0343 - val_rmse: 0.1846
# Epoch 91/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0702 - rmse: 0.2606 - val_loss: 0.0949 - val_rmse: 0.3006
# Epoch 92/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0721 - rmse: 0.2656 - val_loss: 0.0656 - val_rmse: 0.2542
# Epoch 93/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0652 - rmse: 0.2523 - val_loss: 0.0560 - val_rmse: 0.2342
# Epoch 94/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0618 - rmse: 0.2463 - val_loss: 0.0413 - val_rmse: 0.1977
# Epoch 95/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0647 - rmse: 0.2517 - val_loss: 0.0253 - val_rmse: 0.1585
# Epoch 96/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0649 - rmse: 0.2509 - val_loss: 0.1124 - val_rmse: 0.3337
# Epoch 97/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0771 - rmse: 0.2739 - val_loss: 0.0535 - val_rmse: 0.2296
# Epoch 98/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0625 - rmse: 0.2473 - val_loss: 0.0256 - val_rmse: 0.1578
# Epoch 99/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0884 - rmse: 0.2913 - val_loss: 0.0275 - val_rmse: 0.1676
# Epoch 100/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0828 - rmse: 0.2835 - val_loss: 0.0322 - val_rmse: 0.1825
# Epoch 101/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0810 - rmse: 0.2798 - val_loss: 0.0834 - val_rmse: 0.2908
# Epoch 102/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0699 - rmse: 0.2606 - val_loss: 0.0373 - val_rmse: 0.1943
# Epoch 103/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0639 - rmse: 0.2505 - val_loss: 0.0414 - val_rmse: 0.2034
# Epoch 104/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0684 - rmse: 0.2572 - val_loss: 0.0282 - val_rmse: 0.1670
# Epoch 105/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0656 - rmse: 0.2519 - val_loss: 0.0656 - val_rmse: 0.2558
# Epoch 106/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0649 - rmse: 0.2527 - val_loss: 0.0372 - val_rmse: 0.1927
# Epoch 107/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0697 - rmse: 0.2600 - val_loss: 0.0755 - val_rmse: 0.2769
# Epoch 108/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0645 - rmse: 0.2513 - val_loss: 0.0311 - val_rmse: 0.1766
# Epoch 109/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0757 - rmse: 0.2713 - val_loss: 0.0500 - val_rmse: 0.2244
# Epoch 110/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0614 - rmse: 0.2448 - val_loss: 0.0226 - val_rmse: 0.1553
# Epoch 111/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0541 - rmse: 0.2303 - val_loss: 0.0317 - val_rmse: 0.1782
# Epoch 112/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0545 - rmse: 0.2313 - val_loss: 0.0321 - val_rmse: 0.1796
# Epoch 113/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0593 - rmse: 0.2414 - val_loss: 0.0309 - val_rmse: 0.1781
# Epoch 114/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0584 - rmse: 0.2389 - val_loss: 0.0272 - val_rmse: 0.1663
# Epoch 115/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0537 - rmse: 0.2300 - val_loss: 0.0299 - val_rmse: 0.1733
# Epoch 116/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0644 - rmse: 0.2491 - val_loss: 0.0373 - val_rmse: 0.1942
# Epoch 117/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0592 - rmse: 0.2408 - val_loss: 0.0256 - val_rmse: 0.1609
# Epoch 118/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0565 - rmse: 0.2350 - val_loss: 0.0259 - val_rmse: 0.1621
# Epoch 119/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0626 - rmse: 0.2478 - val_loss: 0.0443 - val_rmse: 0.2093
# Epoch 120/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0596 - rmse: 0.2416 - val_loss: 0.0596 - val_rmse: 0.2446
# Epoch 121/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0763 - rmse: 0.2735 - val_loss: 0.0301 - val_rmse: 0.1728
# Epoch 122/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0693 - rmse: 0.2598 - val_loss: 0.0364 - val_rmse: 0.1880
# Epoch 123/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0568 - rmse: 0.2350 - val_loss: 0.0476 - val_rmse: 0.2164
# Epoch 124/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0682 - rmse: 0.2570 - val_loss: 0.0728 - val_rmse: 0.2726
# Epoch 125/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0652 - rmse: 0.2513 - val_loss: 0.0493 - val_rmse: 0.2228
# Epoch 126/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0602 - rmse: 0.2436 - val_loss: 0.0333 - val_rmse: 0.1818
# Epoch 127/600
# 8379/8379 [==============================] - 1s 83us/sample - loss: 0.0471 - rmse: 0.2161 - val_loss: 0.0315 - val_rmse: 0.1795
# Epoch 128/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0512 - rmse: 0.2247 - val_loss: 0.0257 - val_rmse: 0.1614
# Epoch 129/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0587 - rmse: 0.2397 - val_loss: 0.0278 - val_rmse: 0.1660
# Epoch 130/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0772 - rmse: 0.2738 - val_loss: 0.0339 - val_rmse: 0.1793
# Epoch 131/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0598 - rmse: 0.2411 - val_loss: 0.0320 - val_rmse: 0.1808
# Epoch 132/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0688 - rmse: 0.2583 - val_loss: 0.0300 - val_rmse: 0.1711
# Epoch 133/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0629 - rmse: 0.2473 - val_loss: 0.1223 - val_rmse: 0.3541
# Epoch 134/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0828 - rmse: 0.2777 - val_loss: 0.0264 - val_rmse: 0.1650
# Epoch 135/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0556 - rmse: 0.2331 - val_loss: 0.0320 - val_rmse: 0.1802
# Epoch 136/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0502 - rmse: 0.2220 - val_loss: 0.0370 - val_rmse: 0.1939
# Epoch 137/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0742 - rmse: 0.2663 - val_loss: 0.0471 - val_rmse: 0.2197
# Epoch 138/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0616 - rmse: 0.2448 - val_loss: 0.0250 - val_rmse: 0.1588
# Epoch 139/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0574 - rmse: 0.2370 - val_loss: 0.0328 - val_rmse: 0.1804
# Epoch 140/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0545 - rmse: 0.2310 - val_loss: 0.0336 - val_rmse: 0.1845
# Epoch 141/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0526 - rmse: 0.2274 - val_loss: 0.0200 - val_rmse: 0.1434
# Epoch 142/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0483 - rmse: 0.2181 - val_loss: 0.0441 - val_rmse: 0.2131
# Epoch 143/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0639 - rmse: 0.2481 - val_loss: 0.0620 - val_rmse: 0.2477
# Epoch 144/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0435 - rmse: 0.2075 - val_loss: 0.0204 - val_rmse: 0.1417
# Epoch 145/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0498 - rmse: 0.2207 - val_loss: 0.0269 - val_rmse: 0.1647
# Epoch 146/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0542 - rmse: 0.2310 - val_loss: 0.0633 - val_rmse: 0.2521
# Epoch 147/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0613 - rmse: 0.2449 - val_loss: 0.0373 - val_rmse: 0.1946
# Epoch 148/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0527 - rmse: 0.2262 - val_loss: 0.0532 - val_rmse: 0.2281
# Epoch 149/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0622 - rmse: 0.2461 - val_loss: 0.0372 - val_rmse: 0.1952
# Epoch 150/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0501 - rmse: 0.2223 - val_loss: 0.0299 - val_rmse: 0.1733
# Epoch 151/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0475 - rmse: 0.2161 - val_loss: 0.0207 - val_rmse: 0.1433
# Epoch 152/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0572 - rmse: 0.2347 - val_loss: 0.0368 - val_rmse: 0.1932
# Epoch 153/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0565 - rmse: 0.2331 - val_loss: 0.0271 - val_rmse: 0.1649
# Epoch 154/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0613 - rmse: 0.2440 - val_loss: 0.0362 - val_rmse: 0.1892
# Epoch 155/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0519 - rmse: 0.2259 - val_loss: 0.0296 - val_rmse: 0.1726
# Epoch 156/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0552 - rmse: 0.2318 - val_loss: 0.0630 - val_rmse: 0.2476
# Epoch 157/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0580 - rmse: 0.2365 - val_loss: 0.0845 - val_rmse: 0.2911
# Epoch 158/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0524 - rmse: 0.2256 - val_loss: 0.0213 - val_rmse: 0.1477
# Epoch 159/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0451 - rmse: 0.2112 - val_loss: 0.0269 - val_rmse: 0.1642
# Epoch 160/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0457 - rmse: 0.2120 - val_loss: 0.0219 - val_rmse: 0.1457
# Epoch 161/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0477 - rmse: 0.2172 - val_loss: 0.0365 - val_rmse: 0.1899
# Epoch 162/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0634 - rmse: 0.2459 - val_loss: 0.0325 - val_rmse: 0.1733
# Epoch 163/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0600 - rmse: 0.2404 - val_loss: 0.0302 - val_rmse: 0.1764
# Epoch 164/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0587 - rmse: 0.2398 - val_loss: 0.0189 - val_rmse: 0.1381
# Epoch 165/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0500 - rmse: 0.2209 - val_loss: 0.0335 - val_rmse: 0.1842
# Epoch 166/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0675 - rmse: 0.2543 - val_loss: 0.0373 - val_rmse: 0.1907
# Epoch 167/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0482 - rmse: 0.2183 - val_loss: 0.0254 - val_rmse: 0.1634
# Epoch 168/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0465 - rmse: 0.2133 - val_loss: 0.0211 - val_rmse: 0.1430
# Epoch 169/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0570 - rmse: 0.2345 - val_loss: 0.0417 - val_rmse: 0.2055
# Epoch 170/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0538 - rmse: 0.2267 - val_loss: 0.0247 - val_rmse: 0.1563
# Epoch 171/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0550 - rmse: 0.2306 - val_loss: 0.0349 - val_rmse: 0.1878
# Epoch 172/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0470 - rmse: 0.2162 - val_loss: 0.0435 - val_rmse: 0.2089
# Epoch 173/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0605 - rmse: 0.2409 - val_loss: 0.0235 - val_rmse: 0.1528
# Epoch 174/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0496 - rmse: 0.2212 - val_loss: 0.0383 - val_rmse: 0.1971
# Epoch 175/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0511 - rmse: 0.2236 - val_loss: 0.0258 - val_rmse: 0.1604
# Epoch 176/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0431 - rmse: 0.2052 - val_loss: 0.0694 - val_rmse: 0.2643
# Epoch 177/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0483 - rmse: 0.2176 - val_loss: 0.0529 - val_rmse: 0.2310
# Epoch 178/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0581 - rmse: 0.2375 - val_loss: 0.0671 - val_rmse: 0.2605
# Epoch 179/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0542 - rmse: 0.2299 - val_loss: 0.1010 - val_rmse: 0.3181
# Epoch 180/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0499 - rmse: 0.2217 - val_loss: 0.0205 - val_rmse: 0.1439
# Epoch 181/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0635 - rmse: 0.2471 - val_loss: 0.0389 - val_rmse: 0.1985
# Epoch 182/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0533 - rmse: 0.2281 - val_loss: 0.0269 - val_rmse: 0.1625
# Epoch 183/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0430 - rmse: 0.2050 - val_loss: 0.0191 - val_rmse: 0.1377
# Epoch 184/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0413 - rmse: 0.2019 - val_loss: 0.0493 - val_rmse: 0.2226
# Epoch 185/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0558 - rmse: 0.2308 - val_loss: 0.0287 - val_rmse: 0.1707
# Epoch 186/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0395 - rmse: 0.1966 - val_loss: 0.0510 - val_rmse: 0.2263
# Epoch 187/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0402 - rmse: 0.1991 - val_loss: 0.0404 - val_rmse: 0.2007
# Epoch 188/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0474 - rmse: 0.2147 - val_loss: 0.0213 - val_rmse: 0.1482
# Epoch 189/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0425 - rmse: 0.2043 - val_loss: 0.0236 - val_rmse: 0.1502
# Epoch 190/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0493 - rmse: 0.2197 - val_loss: 0.0518 - val_rmse: 0.2278
# Epoch 191/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0634 - rmse: 0.2461 - val_loss: 0.0228 - val_rmse: 0.1494
# Epoch 192/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0464 - rmse: 0.2136 - val_loss: 0.0206 - val_rmse: 0.1439
# Epoch 193/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0653 - rmse: 0.2506 - val_loss: 0.0239 - val_rmse: 0.1557
# Epoch 194/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0479 - rmse: 0.2160 - val_loss: 0.0275 - val_rmse: 0.1667
# Epoch 195/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0429 - rmse: 0.2058 - val_loss: 0.0267 - val_rmse: 0.1635
# Epoch 196/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0493 - rmse: 0.2202 - val_loss: 0.0269 - val_rmse: 0.1633
# Epoch 197/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0427 - rmse: 0.2053 - val_loss: 0.0187 - val_rmse: 0.1376
# Epoch 198/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0391 - rmse: 0.1955 - val_loss: 0.0281 - val_rmse: 0.1679
# Epoch 199/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0474 - rmse: 0.2144 - val_loss: 0.0187 - val_rmse: 0.1363
# Epoch 200/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0417 - rmse: 0.2026 - val_loss: 0.0258 - val_rmse: 0.1595
# Epoch 201/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0412 - rmse: 0.2012 - val_loss: 0.0514 - val_rmse: 0.2263
# Epoch 202/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0414 - rmse: 0.2015 - val_loss: 0.0200 - val_rmse: 0.1377
# Epoch 203/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0456 - rmse: 0.2117 - val_loss: 0.0280 - val_rmse: 0.1646
# Epoch 204/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0428 - rmse: 0.2050 - val_loss: 0.0230 - val_rmse: 0.1519
# Epoch 205/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0417 - rmse: 0.2025 - val_loss: 0.0254 - val_rmse: 0.1624
# Epoch 206/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0524 - rmse: 0.2241 - val_loss: 0.0357 - val_rmse: 0.1928
# Epoch 207/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0437 - rmse: 0.2075 - val_loss: 0.0222 - val_rmse: 0.1468
# Epoch 208/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0379 - rmse: 0.1944 - val_loss: 0.0308 - val_rmse: 0.1745
# Epoch 209/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0445 - rmse: 0.2094 - val_loss: 0.0511 - val_rmse: 0.2290
# Epoch 210/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0587 - rmse: 0.2360 - val_loss: 0.0225 - val_rmse: 0.1497
# Epoch 211/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0380 - rmse: 0.1936 - val_loss: 0.0248 - val_rmse: 0.1581
# Epoch 212/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0423 - rmse: 0.2043 - val_loss: 0.0193 - val_rmse: 0.1354
# Epoch 213/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0357 - rmse: 0.1878 - val_loss: 0.0309 - val_rmse: 0.1763
# Epoch 214/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0470 - rmse: 0.2121 - val_loss: 0.0265 - val_rmse: 0.1628
# Epoch 215/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0485 - rmse: 0.2176 - val_loss: 0.0294 - val_rmse: 0.1718
# Epoch 216/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0378 - rmse: 0.1928 - val_loss: 0.0260 - val_rmse: 0.1603
# Epoch 217/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0408 - rmse: 0.2000 - val_loss: 0.0337 - val_rmse: 0.1823
# Epoch 218/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0507 - rmse: 0.2216 - val_loss: 0.0239 - val_rmse: 0.1544
# Epoch 219/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0513 - rmse: 0.2229 - val_loss: 0.0346 - val_rmse: 0.1843
# Epoch 220/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0459 - rmse: 0.2116 - val_loss: 0.0214 - val_rmse: 0.1440
# Epoch 221/600
# 8379/8379 [==============================] - 1s 83us/sample - loss: 0.0428 - rmse: 0.2044 - val_loss: 0.0445 - val_rmse: 0.2098
# Epoch 222/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0513 - rmse: 0.2213 - val_loss: 0.0356 - val_rmse: 0.1858
# Epoch 223/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0371 - rmse: 0.1907 - val_loss: 0.0261 - val_rmse: 0.1607
# Epoch 224/600
# 8379/8379 [==============================] - 1s 83us/sample - loss: 0.0458 - rmse: 0.2114 - val_loss: 0.0434 - val_rmse: 0.2078
# Epoch 225/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0433 - rmse: 0.2058 - val_loss: 0.0427 - val_rmse: 0.2046
# Epoch 226/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0417 - rmse: 0.2010 - val_loss: 0.0272 - val_rmse: 0.1643
# Epoch 227/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0477 - rmse: 0.2140 - val_loss: 0.0496 - val_rmse: 0.2245
# Epoch 228/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0404 - rmse: 0.1994 - val_loss: 0.0183 - val_rmse: 0.1341
# Epoch 229/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0439 - rmse: 0.2058 - val_loss: 0.0262 - val_rmse: 0.1624
# Epoch 230/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0398 - rmse: 0.1969 - val_loss: 0.0303 - val_rmse: 0.1737
# Epoch 231/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0470 - rmse: 0.2140 - val_loss: 0.0659 - val_rmse: 0.2545
# Epoch 232/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0545 - rmse: 0.2275 - val_loss: 0.0601 - val_rmse: 0.2448
# Epoch 233/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0438 - rmse: 0.2071 - val_loss: 0.0277 - val_rmse: 0.1680
# Epoch 234/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0678 - rmse: 0.2515 - val_loss: 0.0308 - val_rmse: 0.1749
# Epoch 235/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0466 - rmse: 0.2118 - val_loss: 0.0190 - val_rmse: 0.1378
# Epoch 236/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0347 - rmse: 0.1843 - val_loss: 0.0181 - val_rmse: 0.1363
# Epoch 237/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0354 - rmse: 0.1873 - val_loss: 0.0194 - val_rmse: 0.1402
# Epoch 238/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0395 - rmse: 0.1962 - val_loss: 0.0273 - val_rmse: 0.1670
# Epoch 239/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0396 - rmse: 0.1970 - val_loss: 0.0375 - val_rmse: 0.1936
# Epoch 240/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0408 - rmse: 0.1997 - val_loss: 0.0218 - val_rmse: 0.1450
# Epoch 241/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0415 - rmse: 0.2010 - val_loss: 0.0247 - val_rmse: 0.1569
# Epoch 242/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0425 - rmse: 0.2032 - val_loss: 0.0303 - val_rmse: 0.1725
# Epoch 243/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0394 - rmse: 0.1965 - val_loss: 0.0596 - val_rmse: 0.2446
# Epoch 244/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0412 - rmse: 0.1995 - val_loss: 0.0178 - val_rmse: 0.1344
# Epoch 245/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0403 - rmse: 0.1969 - val_loss: 0.0163 - val_rmse: 0.1282
# Epoch 246/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0376 - rmse: 0.1926 - val_loss: 0.0189 - val_rmse: 0.1365
# Epoch 247/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0404 - rmse: 0.1994 - val_loss: 0.0152 - val_rmse: 0.1230
# Epoch 248/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0439 - rmse: 0.2066 - val_loss: 0.0267 - val_rmse: 0.1622
# Epoch 249/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0522 - rmse: 0.2241 - val_loss: 0.0384 - val_rmse: 0.1948
# Epoch 250/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0415 - rmse: 0.2011 - val_loss: 0.0312 - val_rmse: 0.1752
# Epoch 251/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0446 - rmse: 0.2077 - val_loss: 0.0183 - val_rmse: 0.1354
# Epoch 252/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0405 - rmse: 0.1992 - val_loss: 0.0206 - val_rmse: 0.1427
# Epoch 253/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0367 - rmse: 0.1901 - val_loss: 0.0251 - val_rmse: 0.1576
# Epoch 254/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0333 - rmse: 0.1807 - val_loss: 0.0170 - val_rmse: 0.1306
# Epoch 255/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0337 - rmse: 0.1827 - val_loss: 0.0203 - val_rmse: 0.1423
# Epoch 256/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0367 - rmse: 0.1902 - val_loss: 0.0405 - val_rmse: 0.2030
# Epoch 257/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0380 - rmse: 0.1934 - val_loss: 0.0328 - val_rmse: 0.1806
# Epoch 258/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0387 - rmse: 0.1951 - val_loss: 0.0223 - val_rmse: 0.1494
# Epoch 259/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0433 - rmse: 0.2048 - val_loss: 0.0377 - val_rmse: 0.1936
# Epoch 260/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0381 - rmse: 0.1929 - val_loss: 0.0195 - val_rmse: 0.1397
# Epoch 261/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0443 - rmse: 0.2068 - val_loss: 0.0243 - val_rmse: 0.1566
# Epoch 262/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0421 - rmse: 0.2025 - val_loss: 0.0393 - val_rmse: 0.1994
# Epoch 263/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0390 - rmse: 0.1954 - val_loss: 0.0576 - val_rmse: 0.2407
# Epoch 264/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0463 - rmse: 0.2103 - val_loss: 0.0190 - val_rmse: 0.1387
# Epoch 265/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0363 - rmse: 0.1892 - val_loss: 0.0157 - val_rmse: 0.1268
# Epoch 266/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0376 - rmse: 0.1918 - val_loss: 0.0228 - val_rmse: 0.1492
# Epoch 267/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0336 - rmse: 0.1822 - val_loss: 0.0403 - val_rmse: 0.2007
# Epoch 268/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0376 - rmse: 0.1918 - val_loss: 0.0233 - val_rmse: 0.1500
# Epoch 269/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0521 - rmse: 0.2230 - val_loss: 0.0204 - val_rmse: 0.1453
# Epoch 270/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0387 - rmse: 0.1948 - val_loss: 0.0167 - val_rmse: 0.1296
# Epoch 271/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0331 - rmse: 0.1807 - val_loss: 0.0308 - val_rmse: 0.1749
# Epoch 272/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0352 - rmse: 0.1859 - val_loss: 0.0241 - val_rmse: 0.1549
# Epoch 273/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0345 - rmse: 0.1846 - val_loss: 0.0154 - val_rmse: 0.1257
# Epoch 274/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0339 - rmse: 0.1828 - val_loss: 0.0250 - val_rmse: 0.1580
# Epoch 275/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0326 - rmse: 0.1791 - val_loss: 0.0262 - val_rmse: 0.1611
# Epoch 276/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0329 - rmse: 0.1802 - val_loss: 0.0197 - val_rmse: 0.1395
# Epoch 277/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0345 - rmse: 0.1839 - val_loss: 0.0250 - val_rmse: 0.1573
# Epoch 278/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0401 - rmse: 0.1982 - val_loss: 0.0376 - val_rmse: 0.1924
# Epoch 279/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0484 - rmse: 0.2157 - val_loss: 0.0328 - val_rmse: 0.1684
# Epoch 280/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0359 - rmse: 0.1884 - val_loss: 0.0343 - val_rmse: 0.1789
# Epoch 281/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0384 - rmse: 0.1938 - val_loss: 0.0365 - val_rmse: 0.1911
# Epoch 282/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0333 - rmse: 0.1815 - val_loss: 0.0212 - val_rmse: 0.1461
# Epoch 283/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0375 - rmse: 0.1914 - val_loss: 0.0214 - val_rmse: 0.1472
# Epoch 284/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0358 - rmse: 0.1870 - val_loss: 0.0265 - val_rmse: 0.1624
# Epoch 285/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0342 - rmse: 0.1838 - val_loss: 0.0183 - val_rmse: 0.1352
# Epoch 286/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0312 - rmse: 0.1755 - val_loss: 0.0144 - val_rmse: 0.1187
# Epoch 287/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0310 - rmse: 0.1750 - val_loss: 0.0193 - val_rmse: 0.1401
# Epoch 288/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0329 - rmse: 0.1799 - val_loss: 0.0317 - val_rmse: 0.1778
# Epoch 289/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0351 - rmse: 0.1859 - val_loss: 0.0201 - val_rmse: 0.1406
# Epoch 290/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0326 - rmse: 0.1793 - val_loss: 0.0237 - val_rmse: 0.1531
# Epoch 291/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0363 - rmse: 0.1885 - val_loss: 0.0296 - val_rmse: 0.1714
# Epoch 292/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0420 - rmse: 0.2012 - val_loss: 0.0193 - val_rmse: 0.1402
# Epoch 293/600
# 8379/8379 [==============================] - 1s 83us/sample - loss: 0.0326 - rmse: 0.1789 - val_loss: 0.0219 - val_rmse: 0.1489
# Epoch 294/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0445 - rmse: 0.2057 - val_loss: 0.0237 - val_rmse: 0.1580
# Epoch 295/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0383 - rmse: 0.1936 - val_loss: 0.0172 - val_rmse: 0.1302
# Epoch 296/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0371 - rmse: 0.1909 - val_loss: 0.0172 - val_rmse: 0.1324
# Epoch 297/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0379 - rmse: 0.1921 - val_loss: 0.0254 - val_rmse: 0.1573
# Epoch 298/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0306 - rmse: 0.1737 - val_loss: 0.0241 - val_rmse: 0.1588
# Epoch 299/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0407 - rmse: 0.1974 - val_loss: 0.0222 - val_rmse: 0.1483
# Epoch 300/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0371 - rmse: 0.1912 - val_loss: 0.0179 - val_rmse: 0.1358
# Epoch 301/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0333 - rmse: 0.1804 - val_loss: 0.0164 - val_rmse: 0.1269
# Epoch 302/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0314 - rmse: 0.1757 - val_loss: 0.0219 - val_rmse: 0.1490
# Epoch 303/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0316 - rmse: 0.1768 - val_loss: 0.0244 - val_rmse: 0.1570
# Epoch 304/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0318 - rmse: 0.1775 - val_loss: 0.0233 - val_rmse: 0.1528
# Epoch 305/600
# 8379/8379 [==============================] - 1s 83us/sample - loss: 0.0333 - rmse: 0.1804 - val_loss: 0.0222 - val_rmse: 0.1492
# Epoch 306/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0422 - rmse: 0.2027 - val_loss: 0.0709 - val_rmse: 0.2694
# Epoch 307/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0415 - rmse: 0.2012 - val_loss: 0.1521 - val_rmse: 0.3197
# Epoch 308/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0682 - rmse: 0.2569 - val_loss: 0.0369 - val_rmse: 0.1937
# Epoch 309/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0414 - rmse: 0.2006 - val_loss: 0.0264 - val_rmse: 0.1622
# Epoch 310/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0370 - rmse: 0.1904 - val_loss: 0.0166 - val_rmse: 0.1289
# Epoch 311/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0360 - rmse: 0.1875 - val_loss: 0.0207 - val_rmse: 0.1420
# Epoch 312/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0354 - rmse: 0.1867 - val_loss: 0.0315 - val_rmse: 0.1775
# Epoch 313/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0366 - rmse: 0.1887 - val_loss: 0.0177 - val_rmse: 0.1336
# Epoch 314/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0458 - rmse: 0.2088 - val_loss: 0.0219 - val_rmse: 0.1475
# Epoch 315/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0350 - rmse: 0.1859 - val_loss: 0.0192 - val_rmse: 0.1376
# Epoch 316/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0343 - rmse: 0.1837 - val_loss: 0.0153 - val_rmse: 0.1241
# Epoch 317/600
# 8379/8379 [==============================] - 1s 93us/sample - loss: 0.0354 - rmse: 0.1851 - val_loss: 0.0138 - val_rmse: 0.1154
# Epoch 318/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0397 - rmse: 0.1953 - val_loss: 0.0218 - val_rmse: 0.1477
# Epoch 319/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0316 - rmse: 0.1768 - val_loss: 0.0212 - val_rmse: 0.1447
# Epoch 320/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0299 - rmse: 0.1717 - val_loss: 0.0168 - val_rmse: 0.1297
# Epoch 321/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0316 - rmse: 0.1752 - val_loss: 0.0176 - val_rmse: 0.1344
# Epoch 322/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0379 - rmse: 0.1923 - val_loss: 0.0147 - val_rmse: 0.1229
# Epoch 323/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0311 - rmse: 0.1744 - val_loss: 0.0125 - val_rmse: 0.1136
# Epoch 324/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0306 - rmse: 0.1735 - val_loss: 0.0198 - val_rmse: 0.1417
# Epoch 325/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0279 - rmse: 0.1661 - val_loss: 0.0189 - val_rmse: 0.1376
# Epoch 326/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0307 - rmse: 0.1746 - val_loss: 0.0128 - val_rmse: 0.1132
# Epoch 327/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0291 - rmse: 0.1692 - val_loss: 0.0238 - val_rmse: 0.1545
# Epoch 328/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0332 - rmse: 0.1788 - val_loss: 0.0171 - val_rmse: 0.1308
# Epoch 329/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0352 - rmse: 0.1847 - val_loss: 0.0143 - val_rmse: 0.1209
# Epoch 330/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0340 - rmse: 0.1824 - val_loss: 0.0488 - val_rmse: 0.2201
# Epoch 331/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0364 - rmse: 0.1882 - val_loss: 0.0239 - val_rmse: 0.1538
# Epoch 332/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0298 - rmse: 0.1709 - val_loss: 0.0212 - val_rmse: 0.1436
# Epoch 333/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0376 - rmse: 0.1899 - val_loss: 0.0356 - val_rmse: 0.1888
# Epoch 334/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0362 - rmse: 0.1875 - val_loss: 0.0507 - val_rmse: 0.2245
# Epoch 335/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0351 - rmse: 0.1854 - val_loss: 0.0172 - val_rmse: 0.1323
# Epoch 336/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0355 - rmse: 0.1843 - val_loss: 0.0545 - val_rmse: 0.2328
# Epoch 337/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0325 - rmse: 0.1774 - val_loss: 0.0317 - val_rmse: 0.1778
# Epoch 338/600
# 8379/8379 [==============================] - 1s 92us/sample - loss: 0.0339 - rmse: 0.1822 - val_loss: 0.0170 - val_rmse: 0.1291
# Epoch 339/600
# ...
# Epoch 489/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0239 - rmse: 0.1536 - val_loss: 0.0137 - val_rmse: 0.1192
# Epoch 490/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0266 - rmse: 0.1614 - val_loss: 0.0203 - val_rmse: 0.1400
# Epoch 491/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0259 - rmse: 0.1596 - val_loss: 0.0803 - val_rmse: 0.2598
# Epoch 492/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0335 - rmse: 0.1784 - val_loss: 0.0231 - val_rmse: 0.1516
# Epoch 493/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0220 - rmse: 0.1476 - val_loss: 0.0158 - val_rmse: 0.1242
# Epoch 494/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0241 - rmse: 0.1538 - val_loss: 0.0146 - val_rmse: 0.1237
# Epoch 495/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0233 - rmse: 0.1513 - val_loss: 0.0155 - val_rmse: 0.1275
# Epoch 496/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0241 - rmse: 0.1539 - val_loss: 0.0129 - val_rmse: 0.1137
# Epoch 497/600
# 8379/8379 [==============================] - 1s 92us/sample - loss: 0.0235 - rmse: 0.1526 - val_loss: 0.0139 - val_rmse: 0.1176
# Epoch 498/600
# 8379/8379 [==============================] - 1s 91us/sample - loss: 0.0302 - rmse: 0.1712 - val_loss: 0.0145 - val_rmse: 0.1186
# Epoch 499/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0229 - rmse: 0.1506 - val_loss: 0.0127 - val_rmse: 0.1127
# Epoch 500/600
# 8379/8379 [==============================] - 1s 91us/sample - loss: 0.0234 - rmse: 0.1523 - val_loss: 0.0151 - val_rmse: 0.1240
# Epoch 501/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0232 - rmse: 0.1509 - val_loss: 0.0177 - val_rmse: 0.1335
# Epoch 502/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0240 - rmse: 0.1536 - val_loss: 0.0271 - val_rmse: 0.1638
# Epoch 503/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0242 - rmse: 0.1539 - val_loss: 0.0181 - val_rmse: 0.1356
# Epoch 504/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0266 - rmse: 0.1611 - val_loss: 0.0208 - val_rmse: 0.1440
# Epoch 505/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0257 - rmse: 0.1582 - val_loss: 0.0173 - val_rmse: 0.1312
# Epoch 506/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0223 - rmse: 0.1487 - val_loss: 0.0134 - val_rmse: 0.1169
# Epoch 507/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0247 - rmse: 0.1560 - val_loss: 0.0233 - val_rmse: 0.1529
# Epoch 508/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0260 - rmse: 0.1601 - val_loss: 0.0175 - val_rmse: 0.1315
# Epoch 509/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0236 - rmse: 0.1528 - val_loss: 0.0297 - val_rmse: 0.1724
# Epoch 510/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0258 - rmse: 0.1591 - val_loss: 0.0142 - val_rmse: 0.1191
# Epoch 511/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0265 - rmse: 0.1605 - val_loss: 0.0124 - val_rmse: 0.1103
# Epoch 512/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0259 - rmse: 0.1599 - val_loss: 0.0134 - val_rmse: 0.1153
# Epoch 513/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0285 - rmse: 0.1664 - val_loss: 0.0123 - val_rmse: 0.1096
# Epoch 514/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0274 - rmse: 0.1635 - val_loss: 0.0293 - val_rmse: 0.1678
# Epoch 515/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0244 - rmse: 0.1544 - val_loss: 0.0150 - val_rmse: 0.1209
# Epoch 516/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0291 - rmse: 0.1683 - val_loss: 0.0171 - val_rmse: 0.1298
# Epoch 517/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0230 - rmse: 0.1508 - val_loss: 0.0173 - val_rmse: 0.1308
# Epoch 518/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0265 - rmse: 0.1612 - val_loss: 0.0231 - val_rmse: 0.1514
# Epoch 519/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0260 - rmse: 0.1592 - val_loss: 0.0138 - val_rmse: 0.1189
# Epoch 520/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0251 - rmse: 0.1573 - val_loss: 0.0181 - val_rmse: 0.1351
# Epoch 521/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0253 - rmse: 0.1571 - val_loss: 0.0148 - val_rmse: 0.1231
# Epoch 522/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0262 - rmse: 0.1604 - val_loss: 0.0563 - val_rmse: 0.2388
# Epoch 523/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0317 - rmse: 0.1738 - val_loss: 0.0189 - val_rmse: 0.1402
# Epoch 524/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0244 - rmse: 0.1548 - val_loss: 0.0378 - val_rmse: 0.1951
# Epoch 525/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0264 - rmse: 0.1606 - val_loss: 0.0194 - val_rmse: 0.1396
# Epoch 526/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0295 - rmse: 0.1680 - val_loss: 0.0140 - val_rmse: 0.1177
# Epoch 527/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0300 - rmse: 0.1703 - val_loss: 0.0212 - val_rmse: 0.1450
# Epoch 528/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0244 - rmse: 0.1549 - val_loss: 0.0134 - val_rmse: 0.1184
# Epoch 529/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0222 - rmse: 0.1480 - val_loss: 0.0190 - val_rmse: 0.1389
# Epoch 530/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0234 - rmse: 0.1517 - val_loss: 0.0170 - val_rmse: 0.1321
# Epoch 531/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0230 - rmse: 0.1502 - val_loss: 0.0136 - val_rmse: 0.1175
# Epoch 532/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0261 - rmse: 0.1583 - val_loss: 0.0127 - val_rmse: 0.1134
# Epoch 533/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0243 - rmse: 0.1548 - val_loss: 0.0254 - val_rmse: 0.1608
# Epoch 534/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0267 - rmse: 0.1616 - val_loss: 0.0158 - val_rmse: 0.1273
# Epoch 535/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0242 - rmse: 0.1540 - val_loss: 0.0121 - val_rmse: 0.1100
# Epoch 536/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0218 - rmse: 0.1464 - val_loss: 0.0145 - val_rmse: 0.1190
# Epoch 537/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0212 - rmse: 0.1450 - val_loss: 0.0173 - val_rmse: 0.1319
# Epoch 538/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0219 - rmse: 0.1471 - val_loss: 0.0169 - val_rmse: 0.1297
# Epoch 539/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0234 - rmse: 0.1518 - val_loss: 0.0137 - val_rmse: 0.1175
# Epoch 540/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0216 - rmse: 0.1462 - val_loss: 0.0152 - val_rmse: 0.1243
# Epoch 541/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0281 - rmse: 0.1659 - val_loss: 0.0238 - val_rmse: 0.1557
# Epoch 542/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0246 - rmse: 0.1552 - val_loss: 0.1553 - val_rmse: 0.2686
# Epoch 543/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0265 - rmse: 0.1611 - val_loss: 0.0165 - val_rmse: 0.1265
# Epoch 544/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0268 - rmse: 0.1621 - val_loss: 0.0231 - val_rmse: 0.1531
# Epoch 545/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0269 - rmse: 0.1623 - val_loss: 0.0283 - val_rmse: 0.1700
# Epoch 546/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0268 - rmse: 0.1606 - val_loss: 0.0117 - val_rmse: 0.1094
# Epoch 547/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0235 - rmse: 0.1516 - val_loss: 0.0155 - val_rmse: 0.1246
# Epoch 548/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0257 - rmse: 0.1582 - val_loss: 0.0156 - val_rmse: 0.1244
# Epoch 549/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0311 - rmse: 0.1723 - val_loss: 0.0467 - val_rmse: 0.2165
# Epoch 550/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0343 - rmse: 0.1805 - val_loss: 0.0122 - val_rmse: 0.1103
# Epoch 551/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0233 - rmse: 0.1517 - val_loss: 0.0204 - val_rmse: 0.1454
# Epoch 552/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0250 - rmse: 0.1560 - val_loss: 0.0128 - val_rmse: 0.1139
# Epoch 553/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0234 - rmse: 0.1522 - val_loss: 0.0162 - val_rmse: 0.1264
# Epoch 554/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0220 - rmse: 0.1470 - val_loss: 0.0142 - val_rmse: 0.1204
# Epoch 555/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0233 - rmse: 0.1512 - val_loss: 0.0128 - val_rmse: 0.1133
# Epoch 556/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0266 - rmse: 0.1605 - val_loss: 0.0265 - val_rmse: 0.1647
# Epoch 557/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0245 - rmse: 0.1552 - val_loss: 0.0150 - val_rmse: 0.1224
# Epoch 558/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0231 - rmse: 0.1501 - val_loss: 0.0121 - val_rmse: 0.1101
# Epoch 559/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0205 - rmse: 0.1423 - val_loss: 0.0195 - val_rmse: 0.1392
# Epoch 560/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0205 - rmse: 0.1418 - val_loss: 0.0113 - val_rmse: 0.1072
# Epoch 561/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0235 - rmse: 0.1511 - val_loss: 0.0164 - val_rmse: 0.1274
# Epoch 562/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0236 - rmse: 0.1517 - val_loss: 0.0253 - val_rmse: 0.1619
# Epoch 563/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0256 - rmse: 0.1582 - val_loss: 0.0380 - val_rmse: 0.1949
# Epoch 564/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0241 - rmse: 0.1529 - val_loss: 0.0185 - val_rmse: 0.1384
# Epoch 565/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0232 - rmse: 0.1517 - val_loss: 0.0132 - val_rmse: 0.1142
# Epoch 566/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0216 - rmse: 0.1460 - val_loss: 0.0128 - val_rmse: 0.1139
# Epoch 567/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0224 - rmse: 0.1484 - val_loss: 0.0278 - val_rmse: 0.1671
# Epoch 568/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0269 - rmse: 0.1624 - val_loss: 0.0158 - val_rmse: 0.1253
# Epoch 569/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0241 - rmse: 0.1535 - val_loss: 0.0131 - val_rmse: 0.1149
# Epoch 570/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0243 - rmse: 0.1549 - val_loss: 0.0183 - val_rmse: 0.1351
# Epoch 571/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0251 - rmse: 0.1571 - val_loss: 0.0174 - val_rmse: 0.1329
# Epoch 572/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0299 - rmse: 0.1704 - val_loss: 0.0235 - val_rmse: 0.1516
# Epoch 573/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0319 - rmse: 0.1750 - val_loss: 0.0172 - val_rmse: 0.1307
# Epoch 574/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0234 - rmse: 0.1516 - val_loss: 0.0187 - val_rmse: 0.1380
# Epoch 575/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0230 - rmse: 0.1502 - val_loss: 0.0159 - val_rmse: 0.1267
# Epoch 576/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0236 - rmse: 0.1523 - val_loss: 0.0189 - val_rmse: 0.1364
# Epoch 577/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0235 - rmse: 0.1520 - val_loss: 0.0163 - val_rmse: 0.1281
# Epoch 578/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0206 - rmse: 0.1428 - val_loss: 0.0133 - val_rmse: 0.1142
# Epoch 579/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0212 - rmse: 0.1447 - val_loss: 0.0140 - val_rmse: 0.1185
# Epoch 580/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0226 - rmse: 0.1491 - val_loss: 0.0185 - val_rmse: 0.1374
# Epoch 581/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0318 - rmse: 0.1738 - val_loss: 0.0166 - val_rmse: 0.1299
# Epoch 582/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0220 - rmse: 0.1470 - val_loss: 0.0152 - val_rmse: 0.1235
# Epoch 583/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0218 - rmse: 0.1469 - val_loss: 0.0138 - val_rmse: 0.1191
# Epoch 584/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0262 - rmse: 0.1586 - val_loss: 0.0138 - val_rmse: 0.1182
# Epoch 585/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0252 - rmse: 0.1557 - val_loss: 0.0184 - val_rmse: 0.1372
# Epoch 586/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0215 - rmse: 0.1457 - val_loss: 0.0122 - val_rmse: 0.1100
# Epoch 587/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0210 - rmse: 0.1438 - val_loss: 0.0155 - val_rmse: 0.1271
# Epoch 588/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0277 - rmse: 0.1642 - val_loss: 0.0159 - val_rmse: 0.1264
# Epoch 589/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0224 - rmse: 0.1485 - val_loss: 0.0127 - val_rmse: 0.1132
# Epoch 590/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0194 - rmse: 0.1386 - val_loss: 0.0125 - val_rmse: 0.1134
# Epoch 591/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0215 - rmse: 0.1456 - val_loss: 0.0168 - val_rmse: 0.1293
# Epoch 592/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0206 - rmse: 0.1426 - val_loss: 0.0127 - val_rmse: 0.1124
# Epoch 593/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0233 - rmse: 0.1519 - val_loss: 0.0240 - val_rmse: 0.1567
# Epoch 594/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0222 - rmse: 0.1477 - val_loss: 0.0125 - val_rmse: 0.1124
# Epoch 595/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0237 - rmse: 0.1514 - val_loss: 0.0262 - val_rmse: 0.1618
# Epoch 596/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0232 - rmse: 0.1496 - val_loss: 0.0133 - val_rmse: 0.1151
# Epoch 597/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0211 - rmse: 0.1442 - val_loss: 0.0145 - val_rmse: 0.1225
# Epoch 598/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0240 - rmse: 0.1533 - val_loss: 0.0135 - val_rmse: 0.1174
# Epoch 599/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0223 - rmse: 0.1476 - val_loss: 0.0367 - val_rmse: 0.1898
# Epoch 600/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0257 - rmse: 0.1584 - val_loss: 0.0230 - val_rmse: 0.1501

# %%
model_D.load_weights(spath.as_posix())
# Training Progression
plt.figure(figsize=(5.5, 4.25))
epochs = model_D.history.epoch
plt.semilogy(epochs, model_D.history.history['rmse'], label='Train', color='C0')
plt.semilogy(epochs, model_D.history.history['val_rmse'], label='Validation', color='C1')
plt.axhline(0.11, c='k', ls=':', label=f'RMSE = 0.11mm')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('RMSE (mm)')
plt.ylim(1e-1, 1)
plt.text(0, .85, '(a)', bbox={'facecolor':'w', 'edgecolor':'w'}, size=12)
plt.tight_layout()
figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
plt.savefig(figpath / 'D_training.png', dpi=400)

# %%
spath = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/D_3L_71K_BN_D0p2.h5')
model_D.load_weights(spath.as_posix())
metrics = model_D.evaluate(normal(x_test), [1e3*D_test], verbose=0)
y_hat_D = model_D.predict(normal(x_test))

rmse_D = np.mean((y_hat_D.flatten() - 1e3 * D_test.flatten())**2)**0.5
mae_D = np.mean(np.abs(y_hat_D.flatten() - 1e3 * D_test.flatten()))
me_D = np.mean(y_hat_D.flatten() - 1e3 * D_test.flatten())

# %%
plt.figure(figsize=(5.5, 4.5))
plt.plot(1e3 * D_test, y_hat_D, 'k.', alpha=0.1)
plt.plot([6,15],[6, 15], 'r')
plt.axis('equal')
plt.ylabel(r'$\hat{D}$ (mm)')
plt.xlabel('$D$ (mm)')

print(f'RMSE = {rmse_D:.3f}mm')
print(f'MAE = {mae_D:.2f}mm')
figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
plt.savefig(figpath / 'D_Dhat_CNN.png', dpi=400)
# Out:
# RMSE = 0.123mm
# MAE = 0.09mm

# %% [markdown]
# # CNN - $D_{min}$

# %%
# Callbacks
spath = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/Dmin_3L_71K_BN_0p2Dmin.h5')
csv_logger_Dmin = CSVLogger(spath.parent / 'Dmin_3L_71K_BN_0p2D.csv')
reduce_lr_Dmin = ReduceLROnPlateau(patience=100, min_delta=0, factor=0.75)
model_checkpoint_Dmin = ModelCheckpoint(filepath=spath.as_posix(), monitor='val_loss',
                                   save_best_only=True)
callbacks = [model_checkpoint_Dmin, csv_logger_Dmin]

# %%
# Load initialised model (i.e. with initial weights) - stops training getting stuck with stuff stored in GPU mem
ipath = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/D_3L_71K_BN_D0p2_initial.h5')
model_Dmin = tf.keras.models.load_model(ipath, custom_objects={'rmse': rmse})

# Train
model_Dmin.fit(normal(x_train), [1000 * Dmin_train], 
               epochs=600, batch_size=128, 
               validation_data=[normal(x_val), 1e3*Dmin_val], callbacks=callbacks)
# Out:
# Train on 8379 samples, validate on 932 samples
# Epoch 1/600
# 8379/8379 [==============================] - 2s 236us/sample - loss: 7.6329 - rmse: 2.1624 - val_loss: 0.5993 - val_rmse: 0.7685
# Epoch 2/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 1.2185 - rmse: 1.0914 - val_loss: 0.3370 - val_rmse: 0.5805
# Epoch 3/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 1.0109 - rmse: 0.9994 - val_loss: 0.7772 - val_rmse: 0.8605
# Epoch 4/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 1.0283 - rmse: 0.9990 - val_loss: 0.4171 - val_rmse: 0.6478
# Epoch 5/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.8541 - rmse: 0.9141 - val_loss: 0.3129 - val_rmse: 0.5527
# Epoch 6/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.7657 - rmse: 0.8636 - val_loss: 0.3536 - val_rmse: 0.5852
# Epoch 7/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.7835 - rmse: 0.8730 - val_loss: 0.4439 - val_rmse: 0.6645
# Epoch 8/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.5771 - rmse: 0.7506 - val_loss: 0.2336 - val_rmse: 0.4865
# Epoch 9/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.4850 - rmse: 0.6901 - val_loss: 0.2055 - val_rmse: 0.4392
# Epoch 10/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.4307 - rmse: 0.6533 - val_loss: 0.3137 - val_rmse: 0.5571
# Epoch 11/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.4111 - rmse: 0.6386 - val_loss: 0.1936 - val_rmse: 0.4331
# Epoch 12/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.3245 - rmse: 0.5669 - val_loss: 0.1536 - val_rmse: 0.3958
# Epoch 13/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.3095 - rmse: 0.5550 - val_loss: 0.1892 - val_rmse: 0.4441
# Epoch 14/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.3175 - rmse: 0.5604 - val_loss: 0.3258 - val_rmse: 0.5607
# Epoch 15/600
# 8379/8379 [==============================] - 1s 91us/sample - loss: 0.2839 - rmse: 0.5306 - val_loss: 0.1508 - val_rmse: 0.3909
# Epoch 16/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.2715 - rmse: 0.5187 - val_loss: 0.1571 - val_rmse: 0.3917
# Epoch 17/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.2308 - rmse: 0.4786 - val_loss: 0.2292 - val_rmse: 0.4760
# Epoch 18/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.2186 - rmse: 0.4644 - val_loss: 0.1844 - val_rmse: 0.4315
# Epoch 19/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.2074 - rmse: 0.4538 - val_loss: 0.1218 - val_rmse: 0.3466
# Epoch 20/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.2026 - rmse: 0.4481 - val_loss: 0.1100 - val_rmse: 0.3261
# Epoch 21/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.1851 - rmse: 0.4283 - val_loss: 0.0985 - val_rmse: 0.3163
# Epoch 22/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1701 - rmse: 0.4117 - val_loss: 0.1091 - val_rmse: 0.3283
# Epoch 23/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.1660 - rmse: 0.4050 - val_loss: 0.0952 - val_rmse: 0.3046
# Epoch 24/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1490 - rmse: 0.3849 - val_loss: 0.0985 - val_rmse: 0.3088
# Epoch 25/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1539 - rmse: 0.3899 - val_loss: 0.1892 - val_rmse: 0.4340
# Epoch 26/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1852 - rmse: 0.4258 - val_loss: 0.1221 - val_rmse: 0.3468
# Epoch 27/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1659 - rmse: 0.4039 - val_loss: 0.1370 - val_rmse: 0.3645
# Epoch 28/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.1477 - rmse: 0.3816 - val_loss: 0.1260 - val_rmse: 0.3469
# Epoch 29/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1575 - rmse: 0.3929 - val_loss: 0.1223 - val_rmse: 0.3419
# Epoch 30/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.1383 - rmse: 0.3702 - val_loss: 0.1164 - val_rmse: 0.3370
# Epoch 31/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.1449 - rmse: 0.3782 - val_loss: 0.0899 - val_rmse: 0.3025
# Epoch 32/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.1254 - rmse: 0.3529 - val_loss: 0.0851 - val_rmse: 0.2903
# Epoch 33/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.1239 - rmse: 0.3499 - val_loss: 0.0789 - val_rmse: 0.2813
# Epoch 34/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1190 - rmse: 0.3423 - val_loss: 0.0891 - val_rmse: 0.2969
# Epoch 35/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1193 - rmse: 0.3438 - val_loss: 0.0939 - val_rmse: 0.3020
# Epoch 36/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.1220 - rmse: 0.3468 - val_loss: 0.1064 - val_rmse: 0.3231
# Epoch 37/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1433 - rmse: 0.3739 - val_loss: 0.1648 - val_rmse: 0.3967
# Epoch 38/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1344 - rmse: 0.3629 - val_loss: 0.0937 - val_rmse: 0.3028
# Epoch 39/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.1154 - rmse: 0.3361 - val_loss: 0.0695 - val_rmse: 0.2612
# Epoch 40/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1118 - rmse: 0.3321 - val_loss: 0.1357 - val_rmse: 0.3712
# Epoch 41/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1062 - rmse: 0.3243 - val_loss: 0.0801 - val_rmse: 0.2796
# Epoch 42/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1110 - rmse: 0.3303 - val_loss: 0.1755 - val_rmse: 0.4137
# Epoch 43/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.1241 - rmse: 0.3479 - val_loss: 0.0742 - val_rmse: 0.2704
# Epoch 44/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0997 - rmse: 0.3140 - val_loss: 0.1009 - val_rmse: 0.3190
# Epoch 45/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0963 - rmse: 0.3081 - val_loss: 0.0856 - val_rmse: 0.2874
# Epoch 46/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0951 - rmse: 0.3063 - val_loss: 0.0694 - val_rmse: 0.2667
# Epoch 47/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1182 - rmse: 0.3414 - val_loss: 0.1729 - val_rmse: 0.4133
# Epoch 48/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1106 - rmse: 0.3291 - val_loss: 0.0774 - val_rmse: 0.2779
# Epoch 49/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.1097 - rmse: 0.3281 - val_loss: 0.0861 - val_rmse: 0.2914
# Epoch 50/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0949 - rmse: 0.3060 - val_loss: 0.0753 - val_rmse: 0.2710
# Epoch 51/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0907 - rmse: 0.2997 - val_loss: 0.0716 - val_rmse: 0.2669
# Epoch 52/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0865 - rmse: 0.2919 - val_loss: 0.1312 - val_rmse: 0.3639
# Epoch 53/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1142 - rmse: 0.3335 - val_loss: 0.1470 - val_rmse: 0.3787
# Epoch 54/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0993 - rmse: 0.3130 - val_loss: 0.0835 - val_rmse: 0.2869
# Epoch 55/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0954 - rmse: 0.3059 - val_loss: 0.0691 - val_rmse: 0.2582
# Epoch 56/600
# 8379/8379 [==============================] - 1s 91us/sample - loss: 0.1151 - rmse: 0.3367 - val_loss: 0.0682 - val_rmse: 0.2566
# Epoch 57/600
# 8379/8379 [==============================] - 1s 83us/sample - loss: 0.1062 - rmse: 0.3228 - val_loss: 0.1109 - val_rmse: 0.3362
# Epoch 58/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.1052 - rmse: 0.3215 - val_loss: 0.0991 - val_rmse: 0.3079
# Epoch 59/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1132 - rmse: 0.3320 - val_loss: 0.0683 - val_rmse: 0.2567
# Epoch 60/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0955 - rmse: 0.3058 - val_loss: 0.0692 - val_rmse: 0.2590
# Epoch 61/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0838 - rmse: 0.2877 - val_loss: 0.1001 - val_rmse: 0.3149
# Epoch 62/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1126 - rmse: 0.3306 - val_loss: 0.1264 - val_rmse: 0.3555
# Epoch 63/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0985 - rmse: 0.3109 - val_loss: 0.0914 - val_rmse: 0.3023
# Epoch 64/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0823 - rmse: 0.2864 - val_loss: 0.0779 - val_rmse: 0.2786
# Epoch 65/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0851 - rmse: 0.2895 - val_loss: 0.0963 - val_rmse: 0.3061
# Epoch 66/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.1012 - rmse: 0.3140 - val_loss: 0.1140 - val_rmse: 0.3363
# Epoch 67/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.1058 - rmse: 0.3202 - val_loss: 0.1200 - val_rmse: 0.3495
# Epoch 68/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.1134 - rmse: 0.3298 - val_loss: 0.0739 - val_rmse: 0.2694
# Epoch 69/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.1133 - rmse: 0.3303 - val_loss: 0.0702 - val_rmse: 0.2591
# Epoch 70/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0952 - rmse: 0.3066 - val_loss: 0.0960 - val_rmse: 0.3083
# Epoch 71/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.1020 - rmse: 0.3160 - val_loss: 0.1040 - val_rmse: 0.3219
# Epoch 72/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0869 - rmse: 0.2923 - val_loss: 0.0635 - val_rmse: 0.2507
# Epoch 73/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0866 - rmse: 0.2913 - val_loss: 0.1639 - val_rmse: 0.4054
# Epoch 74/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0877 - rmse: 0.2933 - val_loss: 0.0839 - val_rmse: 0.2887
# Epoch 75/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0740 - rmse: 0.2704 - val_loss: 0.0647 - val_rmse: 0.2544
# Epoch 76/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0825 - rmse: 0.2861 - val_loss: 0.1200 - val_rmse: 0.3461
# Epoch 77/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0939 - rmse: 0.3036 - val_loss: 0.0920 - val_rmse: 0.3050
# Epoch 78/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0944 - rmse: 0.3037 - val_loss: 0.0805 - val_rmse: 0.2867
# Epoch 79/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0992 - rmse: 0.3108 - val_loss: 0.0726 - val_rmse: 0.2676
# Epoch 80/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0794 - rmse: 0.2807 - val_loss: 0.0791 - val_rmse: 0.2809
# Epoch 81/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0728 - rmse: 0.2680 - val_loss: 0.0781 - val_rmse: 0.2838
# Epoch 82/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0766 - rmse: 0.2748 - val_loss: 0.0656 - val_rmse: 0.2572
# Epoch 83/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0751 - rmse: 0.2724 - val_loss: 0.0609 - val_rmse: 0.2446
# Epoch 84/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0741 - rmse: 0.2706 - val_loss: 0.1137 - val_rmse: 0.3337
# Epoch 85/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0833 - rmse: 0.2856 - val_loss: 0.0711 - val_rmse: 0.2610
# Epoch 86/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0788 - rmse: 0.2790 - val_loss: 0.1287 - val_rmse: 0.3566
# Epoch 87/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0845 - rmse: 0.2878 - val_loss: 0.0958 - val_rmse: 0.3071
# Epoch 88/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0809 - rmse: 0.2816 - val_loss: 0.0712 - val_rmse: 0.2701
# Epoch 89/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0788 - rmse: 0.2787 - val_loss: 0.1007 - val_rmse: 0.3171
# Epoch 90/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0769 - rmse: 0.2757 - val_loss: 0.0645 - val_rmse: 0.2526
# Epoch 91/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0796 - rmse: 0.2801 - val_loss: 0.1147 - val_rmse: 0.3395
# Epoch 92/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0839 - rmse: 0.2871 - val_loss: 0.1206 - val_rmse: 0.3462
# Epoch 93/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0810 - rmse: 0.2831 - val_loss: 0.0816 - val_rmse: 0.2874
# Epoch 94/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0928 - rmse: 0.3001 - val_loss: 0.0956 - val_rmse: 0.3036
# Epoch 95/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0962 - rmse: 0.3079 - val_loss: 0.0739 - val_rmse: 0.2687
# Epoch 96/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0972 - rmse: 0.3079 - val_loss: 0.0866 - val_rmse: 0.2951
# Epoch 97/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0830 - rmse: 0.2846 - val_loss: 0.0747 - val_rmse: 0.2733
# Epoch 98/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0862 - rmse: 0.2901 - val_loss: 0.0851 - val_rmse: 0.2938
# Epoch 99/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0838 - rmse: 0.2872 - val_loss: 0.0942 - val_rmse: 0.3017
# Epoch 100/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0799 - rmse: 0.2813 - val_loss: 0.0838 - val_rmse: 0.2894
# Epoch 101/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0701 - rmse: 0.2638 - val_loss: 0.0649 - val_rmse: 0.2529
# Epoch 102/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0823 - rmse: 0.2850 - val_loss: 0.0639 - val_rmse: 0.2484
# Epoch 103/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0724 - rmse: 0.2680 - val_loss: 0.0658 - val_rmse: 0.2543
# Epoch 104/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0623 - rmse: 0.2481 - val_loss: 0.0909 - val_rmse: 0.3028
# Epoch 105/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0687 - rmse: 0.2595 - val_loss: 0.0657 - val_rmse: 0.2554
# Epoch 106/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0774 - rmse: 0.2753 - val_loss: 0.0882 - val_rmse: 0.2960
# Epoch 107/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0701 - rmse: 0.2618 - val_loss: 0.0958 - val_rmse: 0.3128
# Epoch 108/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0763 - rmse: 0.2734 - val_loss: 0.0740 - val_rmse: 0.2688
# Epoch 109/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0729 - rmse: 0.2658 - val_loss: 0.1301 - val_rmse: 0.3583
# Epoch 110/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0916 - rmse: 0.2980 - val_loss: 0.0721 - val_rmse: 0.2651
# Epoch 111/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0826 - rmse: 0.2848 - val_loss: 0.0656 - val_rmse: 0.2547
# Epoch 112/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0935 - rmse: 0.3000 - val_loss: 0.0783 - val_rmse: 0.2803
# Epoch 113/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0720 - rmse: 0.2666 - val_loss: 0.0589 - val_rmse: 0.2374
# Epoch 114/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0808 - rmse: 0.2816 - val_loss: 0.0659 - val_rmse: 0.2509
# Epoch 115/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0675 - rmse: 0.2582 - val_loss: 0.0606 - val_rmse: 0.2419
# Epoch 116/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0772 - rmse: 0.2738 - val_loss: 0.0700 - val_rmse: 0.2649
# Epoch 117/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.1235 - rmse: 0.3428 - val_loss: 0.0935 - val_rmse: 0.3056
# Epoch 118/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0943 - rmse: 0.3049 - val_loss: 0.0861 - val_rmse: 0.2932
# Epoch 119/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0818 - rmse: 0.2842 - val_loss: 0.0548 - val_rmse: 0.2358
# Epoch 120/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0740 - rmse: 0.2699 - val_loss: 0.0999 - val_rmse: 0.3153
# Epoch 121/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0848 - rmse: 0.2874 - val_loss: 0.0837 - val_rmse: 0.2817
# Epoch 122/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0774 - rmse: 0.2754 - val_loss: 0.0873 - val_rmse: 0.2951
# Epoch 123/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0643 - rmse: 0.2521 - val_loss: 0.0654 - val_rmse: 0.2513
# Epoch 124/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0659 - rmse: 0.2551 - val_loss: 0.0692 - val_rmse: 0.2622
# Epoch 125/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0616 - rmse: 0.2463 - val_loss: 0.0645 - val_rmse: 0.2512
# Epoch 126/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0617 - rmse: 0.2479 - val_loss: 0.0747 - val_rmse: 0.2660
# Epoch 127/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0732 - rmse: 0.2685 - val_loss: 0.0750 - val_rmse: 0.2733
# Epoch 128/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0653 - rmse: 0.2531 - val_loss: 0.0622 - val_rmse: 0.2462
# Epoch 129/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0598 - rmse: 0.2423 - val_loss: 0.0742 - val_rmse: 0.2716
# Epoch 130/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0662 - rmse: 0.2551 - val_loss: 0.0747 - val_rmse: 0.2687
# Epoch 131/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0616 - rmse: 0.2462 - val_loss: 0.0716 - val_rmse: 0.2671
# Epoch 132/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0647 - rmse: 0.2534 - val_loss: 0.0645 - val_rmse: 0.2501
# Epoch 133/600
# 8379/8379 [==============================] - 1s 83us/sample - loss: 0.0578 - rmse: 0.2387 - val_loss: 0.0573 - val_rmse: 0.2340
# Epoch 134/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0595 - rmse: 0.2427 - val_loss: 0.0595 - val_rmse: 0.2421
# Epoch 135/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0591 - rmse: 0.2421 - val_loss: 0.1003 - val_rmse: 0.3143
# Epoch 136/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0725 - rmse: 0.2654 - val_loss: 0.0640 - val_rmse: 0.2488
# Epoch 137/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0699 - rmse: 0.2594 - val_loss: 0.0672 - val_rmse: 0.2512
# Epoch 138/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0698 - rmse: 0.2597 - val_loss: 0.0680 - val_rmse: 0.2611
# Epoch 139/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0597 - rmse: 0.2418 - val_loss: 0.0573 - val_rmse: 0.2390
# Epoch 140/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0645 - rmse: 0.2514 - val_loss: 0.1370 - val_rmse: 0.3701
# Epoch 141/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0798 - rmse: 0.2773 - val_loss: 0.0704 - val_rmse: 0.2619
# Epoch 142/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0563 - rmse: 0.2360 - val_loss: 0.0698 - val_rmse: 0.2624
# Epoch 143/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0621 - rmse: 0.2468 - val_loss: 0.0677 - val_rmse: 0.2579
# Epoch 144/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0560 - rmse: 0.2352 - val_loss: 0.0573 - val_rmse: 0.2363
# Epoch 145/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0693 - rmse: 0.2596 - val_loss: 0.0623 - val_rmse: 0.2430
# Epoch 146/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0694 - rmse: 0.2599 - val_loss: 0.0676 - val_rmse: 0.2568
# Epoch 147/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0674 - rmse: 0.2543 - val_loss: 0.0548 - val_rmse: 0.2299
# Epoch 148/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0546 - rmse: 0.2321 - val_loss: 0.0549 - val_rmse: 0.2300
# Epoch 149/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0533 - rmse: 0.2300 - val_loss: 0.0630 - val_rmse: 0.2472
# Epoch 150/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0547 - rmse: 0.2329 - val_loss: 0.0538 - val_rmse: 0.2304
# Epoch 151/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0648 - rmse: 0.2520 - val_loss: 0.0752 - val_rmse: 0.2683
# Epoch 152/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0610 - rmse: 0.2454 - val_loss: 0.0563 - val_rmse: 0.2360
# Epoch 153/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0653 - rmse: 0.2523 - val_loss: 0.0625 - val_rmse: 0.2466
# Epoch 154/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0590 - rmse: 0.2415 - val_loss: 0.0739 - val_rmse: 0.2732
# Epoch 155/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0526 - rmse: 0.2279 - val_loss: 0.0498 - val_rmse: 0.2216
# Epoch 156/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0516 - rmse: 0.2257 - val_loss: 0.0642 - val_rmse: 0.2512
# Epoch 157/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0655 - rmse: 0.2537 - val_loss: 0.0897 - val_rmse: 0.2977
# Epoch 158/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0641 - rmse: 0.2494 - val_loss: 0.0635 - val_rmse: 0.2467
# Epoch 159/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0551 - rmse: 0.2334 - val_loss: 0.0627 - val_rmse: 0.2467
# Epoch 160/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0633 - rmse: 0.2493 - val_loss: 0.0570 - val_rmse: 0.2345
# Epoch 161/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0498 - rmse: 0.2219 - val_loss: 0.0695 - val_rmse: 0.2623
# Epoch 162/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0640 - rmse: 0.2502 - val_loss: 0.0883 - val_rmse: 0.2970
# Epoch 163/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0653 - rmse: 0.2525 - val_loss: 0.1333 - val_rmse: 0.3655
# Epoch 164/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0699 - rmse: 0.2608 - val_loss: 0.0705 - val_rmse: 0.2556
# Epoch 165/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0567 - rmse: 0.2363 - val_loss: 0.0564 - val_rmse: 0.2405
# Epoch 166/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0534 - rmse: 0.2300 - val_loss: 0.0760 - val_rmse: 0.2740
# Epoch 167/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0558 - rmse: 0.2337 - val_loss: 0.0556 - val_rmse: 0.2321
# Epoch 168/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0519 - rmse: 0.2258 - val_loss: 0.0783 - val_rmse: 0.2747
# Epoch 169/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0506 - rmse: 0.2231 - val_loss: 0.0798 - val_rmse: 0.2765
# Epoch 170/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0611 - rmse: 0.2426 - val_loss: 0.0535 - val_rmse: 0.2276
# Epoch 171/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0562 - rmse: 0.2357 - val_loss: 0.0924 - val_rmse: 0.3043
# Epoch 172/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0509 - rmse: 0.2230 - val_loss: 0.0502 - val_rmse: 0.2223
# Epoch 173/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0493 - rmse: 0.2209 - val_loss: 0.0774 - val_rmse: 0.2768
# Epoch 174/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0661 - rmse: 0.2520 - val_loss: 0.0559 - val_rmse: 0.2329
# Epoch 175/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0526 - rmse: 0.2279 - val_loss: 0.0629 - val_rmse: 0.2513
# Epoch 176/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0570 - rmse: 0.2355 - val_loss: 0.0554 - val_rmse: 0.2324
# Epoch 177/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0564 - rmse: 0.2361 - val_loss: 0.0750 - val_rmse: 0.2669
# Epoch 178/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0488 - rmse: 0.2193 - val_loss: 0.0584 - val_rmse: 0.2357
# Epoch 179/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0539 - rmse: 0.2297 - val_loss: 0.0631 - val_rmse: 0.2488
# Epoch 180/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0522 - rmse: 0.2267 - val_loss: 0.0600 - val_rmse: 0.2422
# Epoch 181/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0458 - rmse: 0.2126 - val_loss: 0.0599 - val_rmse: 0.2401
# Epoch 182/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0523 - rmse: 0.2262 - val_loss: 0.0558 - val_rmse: 0.2375
# Epoch 183/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0559 - rmse: 0.2343 - val_loss: 0.0603 - val_rmse: 0.2432
# Epoch 184/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0521 - rmse: 0.2266 - val_loss: 0.0563 - val_rmse: 0.2361
# Epoch 185/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0644 - rmse: 0.2494 - val_loss: 0.0637 - val_rmse: 0.2519
# Epoch 186/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0519 - rmse: 0.2258 - val_loss: 0.0522 - val_rmse: 0.2264
# Epoch 187/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0592 - rmse: 0.2402 - val_loss: 0.0712 - val_rmse: 0.2690
# Epoch 188/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0522 - rmse: 0.2268 - val_loss: 0.0664 - val_rmse: 0.2557
# Epoch 189/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0526 - rmse: 0.2271 - val_loss: 0.0697 - val_rmse: 0.2639
# Epoch 190/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0589 - rmse: 0.2393 - val_loss: 0.1061 - val_rmse: 0.3228
# Epoch 191/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0545 - rmse: 0.2311 - val_loss: 0.0634 - val_rmse: 0.2509
# Epoch 192/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0560 - rmse: 0.2348 - val_loss: 0.0543 - val_rmse: 0.2326
# Epoch 193/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0473 - rmse: 0.2165 - val_loss: 0.0800 - val_rmse: 0.2764
# Epoch 194/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0551 - rmse: 0.2330 - val_loss: 0.0612 - val_rmse: 0.2448
# Epoch 195/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0520 - rmse: 0.2246 - val_loss: 0.0579 - val_rmse: 0.2397
# Epoch 196/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0469 - rmse: 0.2148 - val_loss: 0.0524 - val_rmse: 0.2303
# Epoch 197/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0458 - rmse: 0.2115 - val_loss: 0.0608 - val_rmse: 0.2451
# Epoch 198/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0463 - rmse: 0.2129 - val_loss: 0.0763 - val_rmse: 0.2760
# Epoch 199/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0571 - rmse: 0.2372 - val_loss: 0.0753 - val_rmse: 0.2707
# Epoch 200/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0513 - rmse: 0.2243 - val_loss: 0.0630 - val_rmse: 0.2467
# Epoch 201/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0479 - rmse: 0.2170 - val_loss: 0.0794 - val_rmse: 0.2806
# Epoch 202/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0471 - rmse: 0.2158 - val_loss: 0.0719 - val_rmse: 0.2633
# Epoch 203/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0546 - rmse: 0.2305 - val_loss: 0.0576 - val_rmse: 0.2383
# Epoch 204/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0448 - rmse: 0.2113 - val_loss: 0.0492 - val_rmse: 0.2198
# Epoch 205/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0510 - rmse: 0.2238 - val_loss: 0.0624 - val_rmse: 0.2487
# Epoch 206/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0741 - rmse: 0.2667 - val_loss: 0.1146 - val_rmse: 0.3452
# Epoch 207/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0777 - rmse: 0.2747 - val_loss: 0.0798 - val_rmse: 0.2816
# Epoch 208/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0605 - rmse: 0.2443 - val_loss: 0.0519 - val_rmse: 0.2275
# Epoch 209/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0450 - rmse: 0.2108 - val_loss: 0.0604 - val_rmse: 0.2468
# Epoch 210/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0426 - rmse: 0.2052 - val_loss: 0.0534 - val_rmse: 0.2332
# Epoch 211/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0462 - rmse: 0.2130 - val_loss: 0.0528 - val_rmse: 0.2269
# Epoch 212/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0569 - rmse: 0.2342 - val_loss: 0.0616 - val_rmse: 0.2423
# Epoch 213/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0487 - rmse: 0.2181 - val_loss: 0.0722 - val_rmse: 0.2690
# Epoch 214/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0553 - rmse: 0.2318 - val_loss: 0.0499 - val_rmse: 0.2235
# Epoch 215/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0473 - rmse: 0.2160 - val_loss: 0.0667 - val_rmse: 0.2578
# Epoch 216/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0510 - rmse: 0.2229 - val_loss: 0.0545 - val_rmse: 0.2318
# Epoch 217/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0496 - rmse: 0.2212 - val_loss: 0.0550 - val_rmse: 0.2320
# Epoch 218/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0474 - rmse: 0.2157 - val_loss: 0.0502 - val_rmse: 0.2242
# Epoch 219/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0434 - rmse: 0.2070 - val_loss: 0.0599 - val_rmse: 0.2435
# Epoch 220/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0452 - rmse: 0.2110 - val_loss: 0.0635 - val_rmse: 0.2523
# Epoch 221/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0487 - rmse: 0.2188 - val_loss: 0.0697 - val_rmse: 0.2635
# Epoch 222/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0451 - rmse: 0.2102 - val_loss: 0.0527 - val_rmse: 0.2279
# Epoch 223/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0452 - rmse: 0.2111 - val_loss: 0.0570 - val_rmse: 0.2383
# Epoch 224/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0451 - rmse: 0.2109 - val_loss: 0.0510 - val_rmse: 0.2240
# Epoch 225/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0462 - rmse: 0.2131 - val_loss: 0.0712 - val_rmse: 0.2676
# Epoch 226/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0434 - rmse: 0.2068 - val_loss: 0.0585 - val_rmse: 0.2407
# Epoch 227/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0401 - rmse: 0.1987 - val_loss: 0.0811 - val_rmse: 0.2843
# Epoch 228/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0444 - rmse: 0.2092 - val_loss: 0.0542 - val_rmse: 0.2281
# Epoch 229/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0426 - rmse: 0.2044 - val_loss: 0.0496 - val_rmse: 0.2206
# Epoch 230/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0479 - rmse: 0.2170 - val_loss: 0.0545 - val_rmse: 0.2336
# Epoch 231/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0379 - rmse: 0.1939 - val_loss: 0.0532 - val_rmse: 0.2323
# Epoch 232/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0518 - rmse: 0.2246 - val_loss: 0.0483 - val_rmse: 0.2186
# Epoch 233/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0444 - rmse: 0.2087 - val_loss: 0.0598 - val_rmse: 0.2421
# Epoch 234/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0460 - rmse: 0.2116 - val_loss: 0.0890 - val_rmse: 0.2992
# Epoch 235/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0510 - rmse: 0.2242 - val_loss: 0.0527 - val_rmse: 0.2288
# Epoch 236/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0414 - rmse: 0.2020 - val_loss: 0.0519 - val_rmse: 0.2244
# Epoch 237/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0433 - rmse: 0.2065 - val_loss: 0.0520 - val_rmse: 0.2309
# Epoch 238/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0400 - rmse: 0.1991 - val_loss: 0.0560 - val_rmse: 0.2374
# Epoch 239/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0428 - rmse: 0.2060 - val_loss: 0.0510 - val_rmse: 0.2248
# Epoch 240/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0488 - rmse: 0.2193 - val_loss: 0.0485 - val_rmse: 0.2187
# Epoch 241/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0454 - rmse: 0.2101 - val_loss: 0.0592 - val_rmse: 0.2422
# Epoch 242/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0470 - rmse: 0.2144 - val_loss: 0.0621 - val_rmse: 0.2449
# Epoch 243/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0407 - rmse: 0.2002 - val_loss: 0.0516 - val_rmse: 0.2263
# Epoch 244/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0513 - rmse: 0.2226 - val_loss: 0.0516 - val_rmse: 0.2256
# Epoch 245/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0436 - rmse: 0.2067 - val_loss: 0.0514 - val_rmse: 0.2259
# Epoch 246/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0412 - rmse: 0.2018 - val_loss: 0.0460 - val_rmse: 0.2124
# Epoch 247/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0398 - rmse: 0.1981 - val_loss: 0.0547 - val_rmse: 0.2315
# Epoch 248/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0473 - rmse: 0.2153 - val_loss: 0.0526 - val_rmse: 0.2270
# Epoch 249/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0439 - rmse: 0.2078 - val_loss: 0.0478 - val_rmse: 0.2152
# Epoch 250/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0448 - rmse: 0.2101 - val_loss: 0.0448 - val_rmse: 0.2116
# Epoch 251/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0369 - rmse: 0.1911 - val_loss: 0.0456 - val_rmse: 0.2104
# Epoch 252/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0411 - rmse: 0.2012 - val_loss: 0.0639 - val_rmse: 0.2521
# Epoch 253/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0458 - rmse: 0.2116 - val_loss: 0.0595 - val_rmse: 0.2394
# Epoch 254/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0444 - rmse: 0.2081 - val_loss: 0.0508 - val_rmse: 0.2243
# Epoch 255/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0421 - rmse: 0.2034 - val_loss: 0.0607 - val_rmse: 0.2455
# Epoch 256/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0405 - rmse: 0.2000 - val_loss: 0.0465 - val_rmse: 0.2129
# Epoch 257/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0447 - rmse: 0.2091 - val_loss: 0.0626 - val_rmse: 0.2497
# Epoch 258/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0416 - rmse: 0.2026 - val_loss: 0.0547 - val_rmse: 0.2328
# Epoch 259/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0409 - rmse: 0.1998 - val_loss: 0.0487 - val_rmse: 0.2162
# Epoch 260/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0382 - rmse: 0.1946 - val_loss: 0.0469 - val_rmse: 0.2163
# Epoch 261/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0383 - rmse: 0.1938 - val_loss: 0.0726 - val_rmse: 0.2673
# Epoch 262/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0393 - rmse: 0.1970 - val_loss: 0.0568 - val_rmse: 0.2358
# Epoch 263/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0441 - rmse: 0.2082 - val_loss: 0.0648 - val_rmse: 0.2523
# Epoch 264/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0412 - rmse: 0.2016 - val_loss: 0.0526 - val_rmse: 0.2234
# Epoch 265/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0420 - rmse: 0.2032 - val_loss: 0.0449 - val_rmse: 0.2092
# Epoch 266/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0355 - rmse: 0.1879 - val_loss: 0.0512 - val_rmse: 0.2261
# Epoch 267/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0387 - rmse: 0.1957 - val_loss: 0.0500 - val_rmse: 0.2209
# Epoch 268/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0360 - rmse: 0.1888 - val_loss: 0.0450 - val_rmse: 0.2114
# Epoch 269/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0342 - rmse: 0.1840 - val_loss: 0.0653 - val_rmse: 0.2558
# Epoch 270/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0416 - rmse: 0.2016 - val_loss: 0.0467 - val_rmse: 0.2155
# Epoch 271/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0396 - rmse: 0.1970 - val_loss: 0.0491 - val_rmse: 0.2222
# Epoch 272/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0435 - rmse: 0.2071 - val_loss: 0.0485 - val_rmse: 0.2190
# Epoch 273/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0355 - rmse: 0.1875 - val_loss: 0.0464 - val_rmse: 0.2149
# Epoch 274/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0372 - rmse: 0.1921 - val_loss: 0.0502 - val_rmse: 0.2230
# Epoch 275/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0450 - rmse: 0.2098 - val_loss: 0.0593 - val_rmse: 0.2441
# Epoch 276/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0434 - rmse: 0.2067 - val_loss: 0.0515 - val_rmse: 0.2286
# Epoch 277/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0421 - rmse: 0.2031 - val_loss: 0.0539 - val_rmse: 0.2324
# Epoch 278/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0411 - rmse: 0.2012 - val_loss: 0.0455 - val_rmse: 0.2128
# Epoch 279/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0425 - rmse: 0.2045 - val_loss: 0.0483 - val_rmse: 0.2173
# Epoch 280/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0365 - rmse: 0.1901 - val_loss: 0.0607 - val_rmse: 0.2476
# Epoch 281/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0377 - rmse: 0.1932 - val_loss: 0.0456 - val_rmse: 0.2151
# Epoch 282/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0390 - rmse: 0.1954 - val_loss: 0.0519 - val_rmse: 0.2261
# Epoch 283/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0476 - rmse: 0.2147 - val_loss: 0.1246 - val_rmse: 0.3536
# Epoch 284/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0394 - rmse: 0.1962 - val_loss: 0.0440 - val_rmse: 0.2080
# Epoch 285/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0375 - rmse: 0.1923 - val_loss: 0.0519 - val_rmse: 0.2285
# Epoch 286/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0399 - rmse: 0.1973 - val_loss: 0.1071 - val_rmse: 0.3261
# Epoch 287/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0593 - rmse: 0.2382 - val_loss: 0.0466 - val_rmse: 0.2150
# Epoch 288/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0361 - rmse: 0.1886 - val_loss: 0.0453 - val_rmse: 0.2116
# Epoch 289/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0407 - rmse: 0.2001 - val_loss: 0.0454 - val_rmse: 0.2115
# Epoch 290/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0326 - rmse: 0.1803 - val_loss: 0.0462 - val_rmse: 0.2144
# Epoch 291/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0323 - rmse: 0.1790 - val_loss: 0.0494 - val_rmse: 0.2209
# Epoch 292/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0372 - rmse: 0.1914 - val_loss: 0.0465 - val_rmse: 0.2157
# Epoch 293/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0321 - rmse: 0.1788 - val_loss: 0.0496 - val_rmse: 0.2220
# Epoch 294/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0348 - rmse: 0.1854 - val_loss: 0.0487 - val_rmse: 0.2221
# Epoch 295/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0382 - rmse: 0.1942 - val_loss: 0.0476 - val_rmse: 0.2171
# Epoch 296/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0425 - rmse: 0.2036 - val_loss: 0.0461 - val_rmse: 0.2153
# Epoch 297/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0391 - rmse: 0.1960 - val_loss: 0.0479 - val_rmse: 0.2182
# Epoch 298/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0353 - rmse: 0.1864 - val_loss: 0.0438 - val_rmse: 0.2089
# Epoch 299/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0324 - rmse: 0.1792 - val_loss: 0.0446 - val_rmse: 0.2091
# Epoch 300/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0371 - rmse: 0.1910 - val_loss: 0.0516 - val_rmse: 0.2285
# Epoch 301/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0414 - rmse: 0.2003 - val_loss: 0.0570 - val_rmse: 0.2374
# Epoch 302/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0451 - rmse: 0.2101 - val_loss: 0.0659 - val_rmse: 0.2585
# Epoch 303/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0330 - rmse: 0.1807 - val_loss: 0.0501 - val_rmse: 0.2233
# Epoch 304/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0337 - rmse: 0.1825 - val_loss: 0.0671 - val_rmse: 0.2586
# Epoch 305/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0409 - rmse: 0.1991 - val_loss: 0.0477 - val_rmse: 0.2209
# Epoch 306/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0332 - rmse: 0.1810 - val_loss: 0.0513 - val_rmse: 0.2273
# Epoch 307/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0339 - rmse: 0.1829 - val_loss: 0.0508 - val_rmse: 0.2233
# Epoch 308/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0319 - rmse: 0.1777 - val_loss: 0.0435 - val_rmse: 0.2097
# Epoch 309/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0394 - rmse: 0.1951 - val_loss: 0.0697 - val_rmse: 0.2635
# Epoch 310/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0407 - rmse: 0.1992 - val_loss: 0.0462 - val_rmse: 0.2140
# Epoch 311/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0413 - rmse: 0.2009 - val_loss: 0.0935 - val_rmse: 0.3067
# Epoch 312/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0387 - rmse: 0.1938 - val_loss: 0.0585 - val_rmse: 0.2407
# Epoch 313/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0377 - rmse: 0.1920 - val_loss: 0.0462 - val_rmse: 0.2134
# Epoch 314/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0317 - rmse: 0.1780 - val_loss: 0.0500 - val_rmse: 0.2212
# Epoch 315/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0376 - rmse: 0.1912 - val_loss: 0.0503 - val_rmse: 0.2223
# Epoch 316/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0381 - rmse: 0.1927 - val_loss: 0.0574 - val_rmse: 0.2412
# Epoch 317/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0326 - rmse: 0.1799 - val_loss: 0.0468 - val_rmse: 0.2148
# Epoch 318/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0361 - rmse: 0.1885 - val_loss: 0.0510 - val_rmse: 0.2242
# Epoch 319/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0384 - rmse: 0.1933 - val_loss: 0.0558 - val_rmse: 0.2351
# Epoch 320/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0370 - rmse: 0.1903 - val_loss: 0.0560 - val_rmse: 0.2360
# Epoch 321/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0416 - rmse: 0.2003 - val_loss: 0.0656 - val_rmse: 0.2556
# Epoch 322/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0322 - rmse: 0.1785 - val_loss: 0.0519 - val_rmse: 0.2267
# Epoch 323/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0378 - rmse: 0.1924 - val_loss: 0.0443 - val_rmse: 0.2081
# Epoch 324/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0360 - rmse: 0.1879 - val_loss: 0.0538 - val_rmse: 0.2319
# Epoch 325/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0354 - rmse: 0.1863 - val_loss: 0.0460 - val_rmse: 0.2119
# Epoch 326/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0407 - rmse: 0.1980 - val_loss: 0.0686 - val_rmse: 0.2616
# Epoch 327/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0345 - rmse: 0.1850 - val_loss: 0.0591 - val_rmse: 0.2420
# Epoch 328/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0329 - rmse: 0.1805 - val_loss: 0.0528 - val_rmse: 0.2284
# Epoch 329/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0367 - rmse: 0.1899 - val_loss: 0.0470 - val_rmse: 0.2161
# Epoch 330/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0319 - rmse: 0.1775 - val_loss: 0.0577 - val_rmse: 0.2380
# Epoch 331/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0373 - rmse: 0.1911 - val_loss: 0.0452 - val_rmse: 0.2086
# Epoch 332/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0330 - rmse: 0.1798 - val_loss: 0.0477 - val_rmse: 0.2169
# Epoch 333/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0463 - rmse: 0.2101 - val_loss: 0.0629 - val_rmse: 0.2519
# Epoch 334/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0369 - rmse: 0.1910 - val_loss: 0.0523 - val_rmse: 0.2278
# Epoch 335/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0559 - rmse: 0.2286 - val_loss: 0.0543 - val_rmse: 0.2309
# Epoch 336/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0344 - rmse: 0.1838 - val_loss: 0.0438 - val_rmse: 0.2059
# Epoch 337/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0353 - rmse: 0.1865 - val_loss: 0.0524 - val_rmse: 0.2269
# Epoch 338/600
# 8379/8379 [==============================] - 1s 84us/sample - loss: 0.0320 - rmse: 0.1783 - val_loss: 0.0865 - val_rmse: 0.2934
# Epoch 339/600
# ...
# Epoch 489/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0260 - rmse: 0.1604 - val_loss: 0.0418 - val_rmse: 0.2042
# Epoch 490/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0271 - rmse: 0.1627 - val_loss: 0.0450 - val_rmse: 0.2108
# Epoch 491/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0229 - rmse: 0.1507 - val_loss: 0.0427 - val_rmse: 0.2030
# Epoch 492/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0272 - rmse: 0.1627 - val_loss: 0.0436 - val_rmse: 0.2070
# Epoch 493/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0269 - rmse: 0.1627 - val_loss: 0.0532 - val_rmse: 0.2275
# Epoch 494/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0269 - rmse: 0.1629 - val_loss: 0.0435 - val_rmse: 0.2062
# Epoch 495/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0280 - rmse: 0.1663 - val_loss: 0.0459 - val_rmse: 0.2134
# Epoch 496/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0242 - rmse: 0.1541 - val_loss: 0.0415 - val_rmse: 0.2005
# Epoch 497/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0266 - rmse: 0.1618 - val_loss: 0.0454 - val_rmse: 0.2104
# Epoch 498/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0288 - rmse: 0.1673 - val_loss: 0.0499 - val_rmse: 0.2212
# Epoch 499/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0266 - rmse: 0.1624 - val_loss: 0.0454 - val_rmse: 0.2083
# Epoch 500/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0286 - rmse: 0.1672 - val_loss: 0.0473 - val_rmse: 0.2150
# Epoch 501/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0256 - rmse: 0.1587 - val_loss: 0.0449 - val_rmse: 0.2095
# Epoch 502/600
# 8379/8379 [==============================] - 1s 89us/sample - loss: 0.0246 - rmse: 0.1559 - val_loss: 0.0416 - val_rmse: 0.2017
# Epoch 503/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0290 - rmse: 0.1680 - val_loss: 0.0437 - val_rmse: 0.2069
# Epoch 504/600
# 8379/8379 [==============================] - 1s 90us/sample - loss: 0.0261 - rmse: 0.1605 - val_loss: 0.0406 - val_rmse: 0.1984
# Epoch 505/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0310 - rmse: 0.1727 - val_loss: 0.0418 - val_rmse: 0.2011
# Epoch 506/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0257 - rmse: 0.1585 - val_loss: 0.0477 - val_rmse: 0.2193
# Epoch 507/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0256 - rmse: 0.1586 - val_loss: 0.0450 - val_rmse: 0.2094
# Epoch 508/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0353 - rmse: 0.1844 - val_loss: 0.0559 - val_rmse: 0.2330
# Epoch 509/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0282 - rmse: 0.1653 - val_loss: 0.0443 - val_rmse: 0.2109
# Epoch 510/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0268 - rmse: 0.1622 - val_loss: 0.0522 - val_rmse: 0.2259
# Epoch 511/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0248 - rmse: 0.1562 - val_loss: 0.0433 - val_rmse: 0.2052
# Epoch 512/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0306 - rmse: 0.1725 - val_loss: 0.0434 - val_rmse: 0.2070
# Epoch 513/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0283 - rmse: 0.1659 - val_loss: 0.0445 - val_rmse: 0.2079
# Epoch 514/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0274 - rmse: 0.1639 - val_loss: 0.0489 - val_rmse: 0.2184
# Epoch 515/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0247 - rmse: 0.1561 - val_loss: 0.0427 - val_rmse: 0.2019
# Epoch 516/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0252 - rmse: 0.1573 - val_loss: 0.0444 - val_rmse: 0.2093
# Epoch 517/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0243 - rmse: 0.1550 - val_loss: 0.0492 - val_rmse: 0.2202
# Epoch 518/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0283 - rmse: 0.1656 - val_loss: 0.0501 - val_rmse: 0.2212
# Epoch 519/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0238 - rmse: 0.1536 - val_loss: 0.0522 - val_rmse: 0.2256
# Epoch 520/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0255 - rmse: 0.1582 - val_loss: 0.0619 - val_rmse: 0.2471
# Epoch 521/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0284 - rmse: 0.1665 - val_loss: 0.0439 - val_rmse: 0.2074
# Epoch 522/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0234 - rmse: 0.1517 - val_loss: 0.0506 - val_rmse: 0.2242
# Epoch 523/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0244 - rmse: 0.1552 - val_loss: 0.0568 - val_rmse: 0.2383
# Epoch 524/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0239 - rmse: 0.1530 - val_loss: 0.0426 - val_rmse: 0.2051
# Epoch 525/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0260 - rmse: 0.1595 - val_loss: 0.0513 - val_rmse: 0.2247
# Epoch 526/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0236 - rmse: 0.1527 - val_loss: 0.0483 - val_rmse: 0.2177
# Epoch 527/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0261 - rmse: 0.1591 - val_loss: 0.0436 - val_rmse: 0.2048
# Epoch 528/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0261 - rmse: 0.1603 - val_loss: 0.0517 - val_rmse: 0.2259
# Epoch 529/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0238 - rmse: 0.1530 - val_loss: 0.0482 - val_rmse: 0.2177
# Epoch 530/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0221 - rmse: 0.1476 - val_loss: 0.0431 - val_rmse: 0.2064
# Epoch 531/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0249 - rmse: 0.1557 - val_loss: 0.0726 - val_rmse: 0.2702
# Epoch 532/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0323 - rmse: 0.1759 - val_loss: 0.0512 - val_rmse: 0.2234
# Epoch 533/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0272 - rmse: 0.1638 - val_loss: 0.0440 - val_rmse: 0.2086
# Epoch 534/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0245 - rmse: 0.1554 - val_loss: 0.0432 - val_rmse: 0.2046
# Epoch 535/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0248 - rmse: 0.1566 - val_loss: 0.0438 - val_rmse: 0.2072
# Epoch 536/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0222 - rmse: 0.1483 - val_loss: 0.0440 - val_rmse: 0.2072
# Epoch 537/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0241 - rmse: 0.1544 - val_loss: 0.0510 - val_rmse: 0.2239
# Epoch 538/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0269 - rmse: 0.1623 - val_loss: 0.0466 - val_rmse: 0.2133
# Epoch 539/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0250 - rmse: 0.1570 - val_loss: 0.0473 - val_rmse: 0.2155
# Epoch 540/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0257 - rmse: 0.1590 - val_loss: 0.0438 - val_rmse: 0.2063
# Epoch 541/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0272 - rmse: 0.1633 - val_loss: 0.0468 - val_rmse: 0.2126
# Epoch 542/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0252 - rmse: 0.1571 - val_loss: 0.0492 - val_rmse: 0.2206
# Epoch 543/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0274 - rmse: 0.1631 - val_loss: 0.0466 - val_rmse: 0.2146
# Epoch 544/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0219 - rmse: 0.1475 - val_loss: 0.0526 - val_rmse: 0.2274
# Epoch 545/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0256 - rmse: 0.1585 - val_loss: 0.0505 - val_rmse: 0.2229
# Epoch 546/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0244 - rmse: 0.1547 - val_loss: 0.0419 - val_rmse: 0.2032
# Epoch 547/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0276 - rmse: 0.1641 - val_loss: 0.0439 - val_rmse: 0.2074
# Epoch 548/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0228 - rmse: 0.1502 - val_loss: 0.0566 - val_rmse: 0.2362
# Epoch 549/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0248 - rmse: 0.1553 - val_loss: 0.0431 - val_rmse: 0.2069
# Epoch 550/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0243 - rmse: 0.1544 - val_loss: 0.0681 - val_rmse: 0.2613
# Epoch 551/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0279 - rmse: 0.1648 - val_loss: 0.0435 - val_rmse: 0.2050
# Epoch 552/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0263 - rmse: 0.1609 - val_loss: 0.0478 - val_rmse: 0.2152
# Epoch 553/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0246 - rmse: 0.1564 - val_loss: 0.0516 - val_rmse: 0.2261
# Epoch 554/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0239 - rmse: 0.1542 - val_loss: 0.0455 - val_rmse: 0.2090
# Epoch 555/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0245 - rmse: 0.1549 - val_loss: 0.0429 - val_rmse: 0.2037
# Epoch 556/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0233 - rmse: 0.1515 - val_loss: 0.0473 - val_rmse: 0.2142
# Epoch 557/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0227 - rmse: 0.1496 - val_loss: 0.0484 - val_rmse: 0.2193
# Epoch 558/600
# 8379/8379 [==============================] - 1s 88us/sample - loss: 0.0243 - rmse: 0.1546 - val_loss: 0.0524 - val_rmse: 0.2272
# Epoch 559/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0279 - rmse: 0.1660 - val_loss: 0.0468 - val_rmse: 0.2137
# Epoch 560/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0234 - rmse: 0.1522 - val_loss: 0.0458 - val_rmse: 0.2111
# Epoch 561/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0283 - rmse: 0.1642 - val_loss: 0.0696 - val_rmse: 0.2616
# Epoch 562/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0272 - rmse: 0.1637 - val_loss: 0.0540 - val_rmse: 0.2308
# Epoch 563/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0230 - rmse: 0.1504 - val_loss: 0.0448 - val_rmse: 0.2073
# Epoch 564/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0230 - rmse: 0.1508 - val_loss: 0.0441 - val_rmse: 0.2086
# Epoch 565/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0239 - rmse: 0.1534 - val_loss: 0.0523 - val_rmse: 0.2291
# Epoch 566/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0238 - rmse: 0.1527 - val_loss: 0.0444 - val_rmse: 0.2080
# Epoch 567/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0251 - rmse: 0.1569 - val_loss: 0.0472 - val_rmse: 0.2144
# Epoch 568/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0238 - rmse: 0.1536 - val_loss: 0.0482 - val_rmse: 0.2174
# Epoch 569/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0217 - rmse: 0.1465 - val_loss: 0.0436 - val_rmse: 0.2062
# Epoch 570/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0228 - rmse: 0.1498 - val_loss: 0.0470 - val_rmse: 0.2151
# Epoch 571/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0224 - rmse: 0.1489 - val_loss: 0.0424 - val_rmse: 0.2031
# Epoch 572/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0276 - rmse: 0.1641 - val_loss: 0.0437 - val_rmse: 0.2061
# Epoch 573/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0234 - rmse: 0.1519 - val_loss: 0.0436 - val_rmse: 0.2076
# Epoch 574/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0225 - rmse: 0.1490 - val_loss: 0.0423 - val_rmse: 0.2043
# Epoch 575/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0226 - rmse: 0.1497 - val_loss: 0.0456 - val_rmse: 0.2107
# Epoch 576/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0284 - rmse: 0.1664 - val_loss: 0.0469 - val_rmse: 0.2138
# Epoch 577/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0248 - rmse: 0.1566 - val_loss: 0.0448 - val_rmse: 0.2108
# Epoch 578/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0248 - rmse: 0.1561 - val_loss: 0.0467 - val_rmse: 0.2152
# Epoch 579/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0243 - rmse: 0.1544 - val_loss: 0.0455 - val_rmse: 0.2110
# Epoch 580/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0254 - rmse: 0.1579 - val_loss: 0.0533 - val_rmse: 0.2293
# Epoch 581/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0266 - rmse: 0.1609 - val_loss: 0.0421 - val_rmse: 0.2028
# Epoch 582/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0330 - rmse: 0.1784 - val_loss: 0.0456 - val_rmse: 0.2095
# Epoch 583/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0253 - rmse: 0.1577 - val_loss: 0.0443 - val_rmse: 0.2086
# Epoch 584/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0270 - rmse: 0.1632 - val_loss: 0.0626 - val_rmse: 0.2508
# Epoch 585/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0291 - rmse: 0.1687 - val_loss: 0.0559 - val_rmse: 0.2336
# Epoch 586/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0220 - rmse: 0.1474 - val_loss: 0.0438 - val_rmse: 0.2092
# Epoch 587/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0220 - rmse: 0.1475 - val_loss: 0.0450 - val_rmse: 0.2103
# Epoch 588/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0228 - rmse: 0.1495 - val_loss: 0.0449 - val_rmse: 0.2095
# Epoch 589/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0216 - rmse: 0.1464 - val_loss: 0.0502 - val_rmse: 0.2246
# Epoch 590/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0213 - rmse: 0.1447 - val_loss: 0.0427 - val_rmse: 0.2041
# Epoch 591/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0207 - rmse: 0.1433 - val_loss: 0.0447 - val_rmse: 0.2095
# Epoch 592/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0214 - rmse: 0.1456 - val_loss: 0.0439 - val_rmse: 0.2074
# Epoch 593/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0201 - rmse: 0.1408 - val_loss: 0.0504 - val_rmse: 0.2232
# Epoch 594/600
# 8379/8379 [==============================] - 1s 85us/sample - loss: 0.0260 - rmse: 0.1588 - val_loss: 0.0449 - val_rmse: 0.2105
# Epoch 595/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0246 - rmse: 0.1549 - val_loss: 0.0468 - val_rmse: 0.2145
# Epoch 596/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0219 - rmse: 0.1471 - val_loss: 0.0471 - val_rmse: 0.2157
# Epoch 597/600
# 8379/8379 [==============================] - 1s 87us/sample - loss: 0.0221 - rmse: 0.1480 - val_loss: 0.0453 - val_rmse: 0.2110
# Epoch 598/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0268 - rmse: 0.1617 - val_loss: 0.0436 - val_rmse: 0.2080
# Epoch 599/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0233 - rmse: 0.1510 - val_loss: 0.0440 - val_rmse: 0.2093
# Epoch 600/600
# 8379/8379 [==============================] - 1s 86us/sample - loss: 0.0243 - rmse: 0.1544 - val_loss: 0.0442 - val_rmse: 0.2080

# %%
spath = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/Dmin_3L_71K_BN_0p2Dmin.h5')

model_Dmin.load_weights(spath.as_posix())
metrics_Dmin = model_Dmin.evaluate(normal(x_test), [1000*Dmin_test], verbose=0)

y_hat_Dmin = model_Dmin.predict(normal(x_test))
rmse_Dmin = np.mean((y_hat_Dmin.flatten() - 1e3 * Dmin_test.flatten())**2)**0.5
mae_Dmin = np.mean(np.abs(y_hat_Dmin.flatten() - 1e3 * Dmin_test.flatten()))
me_Dmin = np.mean(y_hat_Dmin.flatten() - 1e3 * Dmin_test.flatten())

# %%
figpath.joinpath('Dmin_training.png').as_posix()
# Out:
# 'C:/Users/casim/Dropbox/Projects/undt-ai/figures/Dmin_training.png'

# %%
spath = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/Dmin_3L_71K_BN_0p2Dmin.h5')
model_Dmin.load_weights(spath.as_posix())
# Training Progression
plt.figure(figsize=(5.5, 4.25))
epochs = model_Dmin.history.epoch
plt.semilogy(epochs, model_Dmin.history.history['rmse'], label='Train', color='C0')
plt.semilogy(epochs, model_Dmin.history.history['val_rmse'], label='Validation', color='C1')
plt.axhline(0.2, c='k', ls=':', label=f'RMSE = 0.20mm')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('RMSE (mm)')
plt.ylim(1e-1, 1)
plt.tight_layout()
plt.text(0, .85, '(b)', bbox={'facecolor':'w', 'edgecolor':'w'}, size=12)

figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
plt.savefig(figpath / 'Dmin_training.png', dpi=400)

# %%
plt.plot(1e3 * Dmin_test, y_hat_Dmin, 'k.', alpha=0.1)
plt.plot([4.5,15],[4.5, 15], 'r')
plt.axis('equal')
plt.ylabel(r'$\hat{D_{min}}$ (mm)'), plt.xlabel(r'$D_{min}$ (mm)')
print(f'RMSE = {rmse_Dmin:.3f}mm')
print(f'MAE = {mae_Dmin:.2f}mm')
figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
plt.savefig(figpath / 'Dmin_Dminhat_CNN.png', dpi=400)
# Out:
# RMSE = 0.213mm
# MAE = 0.15mm

# %% [markdown]
# # Combined CNN Assessment

# %%
fig, axarr = plt.subplots(1, 2, sharey=True, figsize=(9, 4.5))
epochs = model_Dmin.history.epoch
axarr[1].semilogy(epochs, model_Dmin.history.history['rmse'], label='Train')
axarr[1].semilogy(epochs, model_Dmin.history.history['val_rmse'], label='Validation')
axarr[1].axhline(0.21, c='k', ls=':', label=f'RMSE = 0.21 mm')
axarr[1].legend()
axarr[1].set_xlabel('Epoch')
axarr[1].set_ylim(1e-1, 1)

epochs = model_D.history.epoch
axarr[0].semilogy(epochs, model_D.history.history['rmse'], label='Train')
axarr[0].semilogy(epochs, model_D.history.history['val_rmse'], label='Validation')
axarr[0].axhline(0.114, c='k', ls=':', label=f'RMSE = 0.11 mm')
axarr[0].legend()
axarr[0].set_xlabel('Epoch')
axarr[0].set_ylabel('RMSE (mm)')
axarr[0].set_ylim(1e-1, 1)
plt.tight_layout()


figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
plt.savefig(figpath / 'D_Dmin_training.png', dpi=400)

# %%
plt.plot(y_hat_D, y_hat_Dmin, 'k.', alpha=0.1, label='$\hat{y}$')
plt.plot(1e3*D_test, 1e3*Dmin_test, 'r.', alpha=0.1, label='$y$')

#plt.plot([4.5,15],[4.5, 15], 'r')
plt.axis('equal')
plt.ylabel('$D_{min}$ (mm)')
plt.xlabel('$D$ (mm)')
plt.legend()
# Out:
# <>:1: DeprecationWarning: invalid escape sequence \h
# <>:1: DeprecationWarning: invalid escape sequence \h
# <>:1: DeprecationWarning: invalid escape sequence \h
# <ipython-input-236-02ff23279e2b>:1: DeprecationWarning: invalid escape sequence \h
#   plt.plot(y_hat_D, y_hat_Dmin, 'k.', alpha=0.1, label='$\hat{y}$')

# %%
fig, axarr = plt.subplots(1, 2, figsize=(8, 3.5), sharex=True)

axarr[0].plot(1e3 * D_test, y_hat_D, 'k.', alpha=0.1)
axarr[0].plot([5.5,15],[5.5, 15], 'r')
# axarr[1].axis('equal')
axarr[0].set_ylabel(r'$\hat{D}$ (mm)'), axarr[0].set_xlabel(r'$D$ (mm)')


axarr[1].plot(1e3 * Dmin_test, y_hat_Dmin, 'k.', alpha=0.1)
axarr[1].plot([4.5,15],[4.5, 15], 'r')
# axarr[1].axis('equal')
axarr[1].set_ylabel(r'$\hat{D_{min}}$ (mm)'), axarr[1].set_xlabel(r'$D_{min}$ (mm)')

plt.tight_layout()
figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
plt.savefig(figpath / 'D_Dmin_hat_CNN.png', dpi=400)

# %% [markdown]
# # $D_{mean}$ From Peak (NOT Peak of Envelope)
# No longer used!

# %%
D_test.shape
# Out:
# (3104, 1)

# %%
c_fe = 5700  #  (m/s) Approx. speed of sound in stainless steel
offset = 0.85 / 1e6

t, x_flat, Dmin_flat, D_flat, _ = load_single(fpath_sf, crop=45)
t = t[0]
dt = t[1] - t[0]

# Correction via flat plate
peak_est_flat = (D_flat.flatten() * 2 / (c_fe))
peak_offset_flat = peak_est_flat + offset
arg_peak_est_flat = np.argmin(np.abs(t - peak_offset_flat), axis=0)


# Correct on rough data
peak_est = (D_test.flatten() * 2 / (c_fe))
peak_offset = peak_est + offset
arg_peak_est = np.argmin(np.abs(t - peak_offset), axis=0)

# %% [markdown]
# ### Use Flat Plate to Find Velocity/Offset

# %%
c_fe = 5670  #  (m/s) Approx. speed of sound in stainless steel
offset = 0.84 / 1e6

t, x_flat, Dmin_flat, D_flat, _ = load_single(fpath_sf, crop=45)
t = t[0]
dt = t[1] - t[0]

# Correction via flat plate
peak_est_flat = (D_flat.flatten() * 2 / (c_fe))
peak_offset_flat = peak_est_flat + offset
arg_peak_est_flat = np.argmin(np.abs(t - peak_offset_flat), axis=0)

plt.figure(figsize=(10, 5))
for idx, select in enumerate([0, 4,  8, 12, 15, 18, 22]):
    plt.axvline(1e6 * t[arg_peak_est_flat[select]], color=f'C{idx}')
    plt.plot(1e6*t, x_flat[select], color=f'C{idx}', label=f'{1e3 * D_flat[select][0]:.2f}')
plt.legend()
plt.xlim(2, 7)
# Out:
# (2, 7)

# %%
# Use estimated position to iterate and find actual peak
arg_peak = []

for idx, i in enumerate((arg_peak_est * 1.25).astype(int)):
    arg_peak.append(np.argmax(x_test[idx, :i]))

t_0 = offset 
dt_pulse = t[np.array(arg_peak)] - t_0

# %%
y_hat_D_pwin = 1e3 * c_fe * dt_pulse / 2

rmse_D_pwin = np.mean((y_hat_D_pwin.flatten() - 1e3 * D_test.flatten())**2)**0.5
mae_D_pwin = np.mean(np.abs(y_hat_D_pwin.flatten() - 1e3 * D_test.flatten()))
me_D_pwin = np.mean(y_hat_D_pwin.flatten() - 1e3 * D_test.flatten())

# %%
# Viz results
plt.plot(1e3 * D_test, y_hat_D_pwin, 'k.', alpha=0.2)
plt.plot([6, 15], [6, 15], 'r-')
plt.axis('equal')
plt.ylabel(r'$\hat{y}$ (mm)'), plt.xlabel(r'$y$ (mm)')

print(f'RMSE = {rmse_D_pwin:.2f}mm')
print(f'MAE = {mae_D_pwin:.2f}mm')
# Out:
# RMSE = 0.51mm
# MAE = 0.35mm

# %% [markdown]
# # $D_{mean}$ From Peak of Envelope

# %%
D_test.shape
# Out:
# (3104, 1)

# %%
c_fe = 5700  #  (m/s) Approx. speed of sound in stainless steel
offset = 0.8 / 1e6

t, x_flat, Dmin_flat, D_flat, _ = load_single(fpath_sf, crop=45)
t = t[0]
dt = t[1] - t[0]

# Correction via flat plate
peak_est_flat = (D_flat.flatten() * 2 / (c_fe))
peak_offset_flat = peak_est_flat + offset
arg_peak_est_flat = np.argmin(np.abs(t - peak_offset_flat), axis=0)


# Correct on rough data
peak_est = (D_test.flatten() * 2 / (c_fe))
peak_offset = peak_est + offset
arg_peak_est = np.argmin(np.abs(t - peak_offset), axis=0)

# %% [markdown]
# ### Use Flat Plate to Find Velocity/Offset

# %%
c_fe = 5670  #  (m/s) Approx. speed of sound in stainless steel
offset = 0.8 / 1e6

t, x_flat, Dmin_flat, D_flat, _ = load_single(fpath_sf, crop=45)
t = t[0]
dt = t[1] - t[0]

# Correction via flat plate
peak_est_flat = (D_flat.flatten() * 2 / (c_fe))
peak_offset_flat = peak_est_flat + offset
arg_peak_est_flat = np.argmin(np.abs(t - peak_offset_flat), axis=0)

plt.figure(figsize=(10, 5))
for idx, select in enumerate([0, 4,  8, 12, 15, 18, 22]):
    plt.axvline(1e6 * t[arg_peak_est_flat[select]], color=f'C{idx}')
    plt.plot(1e6*t, x_flat[select], color=f'C{idx}', label=f'{1e3 * D_flat[select][0]:.2f}')
plt.legend()
plt.xlim(2, 7)
# Out:
# (2, 7)

# %%
# Use estimated position to iterate and find actual peak
arg_peak = []
arg_thresh = []
window = 50
for idx, i in enumerate((arg_peak_est).astype(int)):
    rand = np.random.randint(3)
    i += rand
    i_min = i - window if i > window else 0
    signal = x_test[idx, i_min:i+window][:,0]
    analytic_signal = hilbert(signal)
    amplitude_envelope = np.abs(analytic_signal)
    amplitude_envelope /= np.max(amplitude_envelope)
    peak_of_envelope = np.argmax(amplitude_envelope) 
    
    env_rev = amplitude_envelope[:peak_of_envelope][::-1]
    thresh = np.argwhere(env_rev < 0.3)[0, 0]
    peak_thresh = peak_of_envelope - thresh
    
    arg_peak.append(peak_of_envelope + i_min)
    arg_thresh.append(peak_thresh + i_min)

t_0 = offset 
dt_pulse_thresh = t[np.array(arg_thresh)] - t_0
dt_pulse = t[np.array(arg_peak)] - t_0

# %%
plt.plot(1e6 * t[i_min:i+window], signal/np.max(np.abs(analytic_signal)), label='Signal', c='0.2')
plt.plot(1e6 * t[i_min:i+window], np.abs(analytic_signal)/np.max(np.abs(analytic_signal)), label='Pulse envelope', c='C3')

plt.axvline(1e6 * t[peak_thresh + i_min], lw=1.5, ls='-.', c='0.2', label='Threshold Crossing')
#plt.plot(1e6 * t[peak_thresh + i_min], np.abs(analytic_signal[peak_thresh])/np.max(np.abs(analytic_signal)), 'ro', label='Threshold Crossing')

plt.axvline(1e6 * t[peak_of_envelope + i_min], c='k', ls='--', label='Peak of Envelope')

plt.xlim(4.3, 7.3)
plt.legend()
plt.xlabel(r'time ($\mu s$)')
plt.ylabel('Normalised amplitude')
plt.tight_layout()
plt.savefig(figpath / 'conventional_approch.png', dpi=400)

# %%
env_rev = amplitude_envelope[:peak_of_envelope][::-1]
thresh = np.argwhere(env_rev < 0.1)[0]
plt.plot(env_rev, '.-')
plt.axvline(thresh, c='k', lw=1)
plt.axhline(0.1, c='k', lw=1, ls=':')
# plt.xlim(10.75, 11.25)
# plt.ylim(0.08, 0.12)
plt.figure()
arg_thresh = peak_of_envelope - thresh
plt.plot(amplitude_envelope[:peak_of_envelope], '.-')
plt.axvline(arg_thresh, c='k', lw=1)
print(amplitude_envelope[arg_thresh])
plt.axhline(0.1, c='k', lw=1, ls=':')
plt.ylim(0, 0.3)
# Out:
# [0.10059695]
# (0, 0.3)

# %%
y_hat_D_pwin = 1e3 * c_fe * dt_pulse / 2

rmse_D_pwin = np.mean((y_hat_D_pwin.flatten() - 1e3 * D_test.flatten())**2)**0.5
mae_D_pwin = np.mean(np.abs(y_hat_D_pwin.flatten() - 1e3 * D_test.flatten()))
me_D_pwin = np.mean(y_hat_D_pwin.flatten() - 1e3 * D_test.flatten())

# %%
# Viz results
plt.plot(1e3 * D_test, y_hat_D_pwin, 'k.', alpha=0.2)
plt.plot([6, 15], [6, 15], 'r-')
plt.axis('equal')
plt.ylabel(r'$\hat{y}$ (mm)'), plt.xlabel(r'$y$ (mm)')

print(f'RMSE = {rmse_D_pwin:.2f}mm')
print(f'MAE = {mae_D_pwin:.2f}mm')
# Out:
# RMSE = 0.65mm
# MAE = 0.45mm

# %%
y_hat_Dmin_pwin = 1e3 * c_fe * dt_pulse_thresh / 2

rmse_Dmin_pwin = np.mean((y_hat_Dmin_pwin.flatten() - 1e3 * Dmin_test.flatten())**2)**0.5
mae_Dmin_pwin = np.mean(np.abs(y_hat_Dmin_pwin.flatten() - 1e3 * Dmin_test.flatten()))
me_Dmin_pwin = np.mean(y_hat_Dmin_pwin.flatten() - 1e3 * Dmin_test.flatten())

# %%
# Viz results
plt.plot(1e3 * Dmin_test, y_hat_Dmin_pwin[:, 0], 'k.', alpha=0.2)
plt.plot([6, 15], [6, 15], 'r-')
plt.axis('equal')
plt.ylabel(r'$\hat{y}$ (mm)'), plt.xlabel(r'$y$ (mm)')

print(f'RMSE = {rmse_Dmin_pwin:.2f}mm')
print(f'MAE = {mae_Dmin_pwin:.2f}mm')
# Out:
# RMSE = 0.70mm
# MAE = 0.46mm

# %%
plt.plot(y_hat_D_pwin, y_hat_Dmin_pwin, 'k.', alpha=0.2)
plt.plot([5, 15], [5, 15], 'r-')
plt.axis('equal')
plt.ylabel(r'$\hat{y}$ (mm)')
plt.xlabel(r'$y$ (mm)')
# Out:
# Text(0.5, 0, '$y$ (mm)')

# %% [markdown]
# # Comparison

# %%
fig, axarr = plt.subplots(1,2, sharex=True,sharey=True, figsize=(8.5, 4.25))
kwargs = {'cumulative': True}
sns.distplot(1e3 * D_test - y_hat_D, 
             ax=axarr[0], bins=np.linspace(-3, 3, 91), label=r'$D^{CNN}$')
sns.distplot(1e3 * Dmin_test - y_hat_Dmin, 
             ax=axarr[1], bins=np.linspace(-3, 3, 91), label=r'$D_{min}^{CNN}$')

sns.distplot(1e3 * D_test - y_hat_D_pwin, 
             ax=axarr[0], bins=np.linspace(-3, 3, 91), color='C1', label=r'$D^{peak}$')

sns.distplot(1e3 * Dmin_test - y_hat_Dmin_pwin, 
             ax=axarr[1], bins=np.linspace(-3, 3, 91), color='C1', label=r'$D_{min}^{thresh}$')


for ax in axarr.flatten():
    ax.legend()

axarr[0].set_xlim(-1.7, 1.7)

# axarr[0].set_ylim(axarr[0].get_ylim())
# axarr[1].set_yticklabels([])
axarr[0].text(-1.5, 4.4, r'(a) $D$', size=14)
axarr[1].text(-1.5, 4.4, r'(b) $D_{min}$', size=14)


axarr[0].set_xlabel(r'$ D - \hat{D}$ (mm)')
axarr[1].set_xlabel(r'$ D_{min} - \hat{D}_{min}$ (mm)')

axarr[0].set_ylabel(r'Density')

fig.tight_layout()

figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
fig.savefig(figpath / 'D_Dmin_distribution_simple.png', dpi=400)

# %%
fig, axarr = plt.subplots(2, 2, sharex=True, figsize=(8, 7.25))
kwargs = {'cumulative': True}
sns.distplot(1e3 * D_test - y_hat_D, 
             ax=axarr[0, 0], bins=np.linspace(-3, 3, 91), label=r'$D^{CNN}$')
sns.distplot(1e3 * Dmin_test - y_hat_Dmin, 
             ax=axarr[0, 1], bins=np.linspace(-3, 3, 91), label=r'$D_{min}^{CNN}$')

sns.distplot(1e3 * D_test - y_hat_D_pwin, 
             ax=axarr[0, 0], bins=np.linspace(-3, 3, 91), color='C1', label=r'$D^{peak}$')

sns.distplot(1e3 * Dmin_test - y_hat_Dmin_pwin, 
             ax=axarr[0, 1], bins=np.linspace(-3, 3, 91), color='C1', label=r'$D_{min}^{thresh}$')


sns.distplot(1e3 * D_test - y_hat_D, hist_kws=kwargs, 
             kde_kws=kwargs, ax=axarr[1, 0], bins=np.linspace(-3, 3, 91), label=r'$D^{CNN}$')

sns.distplot(1e3 * Dmin_test - y_hat_Dmin, hist_kws=kwargs, 
             kde_kws=kwargs, ax=axarr[1, 1], bins=np.linspace(-3, 3, 91), label=r'$D_{min}^{CNN}$')

sns.distplot(1e3 * D_test - y_hat_D_pwin, hist_kws=kwargs, kde_kws=kwargs, 
             ax=axarr[1, 0], bins=np.linspace(-3, 3, 91), color='C1', label=r'$D^{peak}$')
sns.distplot(1e3 * Dmin_test - y_hat_Dmin_pwin, hist_kws=kwargs, kde_kws=kwargs, 
             ax=axarr[1, 1], bins=np.linspace(-3, 3, 91), color='C1', label=r'$D_{min}^{thresh}$')

for ax in axarr.flatten():
    ax.legend()

axarr[0, 0].set_xlim(-1.5, 1.5)

axarr[0, 1].set_ylim(axarr[0, 0].get_ylim())
axarr[0, 1].set_yticklabels([])
axarr[1, 1].set_yticklabels([])
axarr[0, 0].set_title(r'$D$', size=14)
axarr[0, 1].set_title(r'$D_{min}$', size=14)


axarr[1, 0].set_xlabel(r'$ D - \hat{D}$ (mm)')
axarr[1, 1].set_xlabel(r'$ D_{min} - \hat{D}_{min}$ (mm)')

axarr[0, 0].set_ylabel(r'Density')
axarr[1, 0].set_ylabel(r'Probability')

axarr[0,0].text
fig.tight_layout()

figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
fig.savefig(figpath / 'D_Dmin_distribution.png', dpi=400)

# %%
fig, axarr = plt.subplots(2, 2, figsize=(8., 7.25), sharex=True, sharey=True)

axarr[0, 0].plot(1e3 * D_test, y_hat_D, 'k.', alpha=0.1, label=r'$D^{CNN}$')
axarr[0, 0].plot([5.5,15.5],[5.5, 15.5], 'r', label=r'$D=\hat{D}$')
# axarr[1].axis('equal')
axarr[0, 0].set_ylabel(r'$\hat{y}$ (mm)'), axarr[1, 0].set_xlabel(r'$y$ (mm)')
axarr[0, 0].legend()
axarr[0, 0].set_title(r'$D$', size=14)
axarr[0, 1].set_title(r'$D_{min}$', size=14)

axarr[0, 1].plot(1e3 * Dmin_test, y_hat_Dmin, 'k.', alpha=0.1, label=r'$D_{min}^{CNN}$')
axarr[0, 1].plot([4.5,15],[4.5, 15], 'r', label=r'$D_{min}=\hat{D}_{min}$')
axarr[0, 1].legend()
# axarr[0, 1].set_ylabel(r'$\hat{D_{min}}$ (mm)')
axarr[1, 1].set_xlabel(r'$y$ (mm)')


axarr[1, 0].plot(1e3 * D_test, y_hat_D_pwin, 'k.', alpha=0.1, label=r'$D^{peak}$')
axarr[1, 0].plot([5.5,15.5],[5.5, 15.5], 'r', label=r'$D=\hat{D}$')
axarr[1, 0].set_ylabel(r'$\hat{y}$ (mm)')
axarr[1, 0].legend()

axarr[1, 1].plot(1e3 * Dmin_test, y_hat_Dmin_pwin, 'k.', alpha=0.1, label=r'$D_{min}^{thresh}$')
axarr[1, 1].plot([4.5,15],[4.5, 15], 'r', label=r'$D_{min}=\hat{D}_{min}$')
#axarr[1, 1].set_ylabel(r'$\hat{D_{min}}$ (mm)'), 
axarr[1, 1].set_ylim(3.8, 16.2)
axarr[1, 1].legend()


plt.tight_layout()
figpath = Path.home().joinpath('Dropbox/Projects/undt-ai/figures/')
plt.savefig(figpath / 'D_Dmin_hat_CNN.png', dpi=400)

# %% [markdown]
# # Old Plots- needs to be rerun to include

# %%
# Dmin - needs to be rerun with new results!!
plt.plot(1e3 * Dmin_test, y_hat_Dmin_pwin, 'k.', alpha=0.2, label=f'Thresh: {rmse_Dmin_pth:.2f} mm')
plt.plot(1e3 * Dmin_test, y_hat_Dmin, 'r.', alpha=0.2, label=f'CNN: {rmse_Dmin:.2f} mm')
plt.legend()
plt.axis('equal')
plt.ylabel('$\hat{y}$ (mm)')
plt.xlabel('$y$ (mm)')
plt.tight_layout()
# Out:
# <>:6: DeprecationWarning: invalid escape sequence \h
# <>:6: DeprecationWarning: invalid escape sequence \h
# <>:6: DeprecationWarning: invalid escape sequence \h
# <ipython-input-73-8d6350496357>:6: DeprecationWarning: invalid escape sequence \h
#   plt.ylabel('$\hat{y}$ (mm)')
# Text(0.5, 0, '$y$ (mm)')

# %%
#sns.distplot(1e3 * Dmin_test - y_hat_Dmin_pval, kde=True)
kwargs = {'cumulative': True}
sns.distplot(1e3 * Dmin_test - y_hat_Dmin_pwin, hist_kws=kwargs, kde_kws=kwargs, label=f'ZC: ±{rmse_Dmin_pth:.2f}')
sns.distplot(1e3 * Dmin_test - y_hat_Dmin, hist_kws=kwargs, kde_kws=kwargs, label=f'CNN: ±{rmse_Dmin:.2f}')
plt.xlim(-3, 3)
plt.ylabel('Probability')
plt.legend()
plt.xlabel(r'$ D_{min} - \hat{D}_{min}$ (mm)')
plt.tight_layout()

# %%
# Dmean - needs to be rerun with new results!!
plt.figure(figsize=(5.5, 4.5))
plt.plot(1e3 * D_test, y_hat_D_pwin, 'k.', alpha=0.2, label=f'Thresh: RMSE = {rmse_D_pwin:.2f}')
plt.plot(1e3 * D_test, y_hat_D, 'r.', alpha=0.2, label=f'CNN: RMSE = {rmse_D:.2f}')
plt.legend()
plt.axis('equal')
plt.ylabel(r'$\hat{y}$ (mm)')
plt.xlabel('$y$ (mm)')
plt.ylim(3.7, 16.3)
plt.tight_layout()
plt.save_fig

# %%
#sns.distplot(1e3 * Dmin_test - y_hat_Dmin_pval, kde=True)
kwargs = {'cumulative': True}
sns.distplot(1e3 * D_test - y_hat_D_pwin, hist_kws=kwargs, kde_kws=kwargs, label=f'Peak: ±{rmse_D_pwin:.2f}')
#plt.xlim(-3, 3)
#plt.figure()
sns.distplot(1e3 * D_test - y_hat_D, hist_kws=kwargs, kde_kws=kwargs, label=f'CNN: ±{rmse_D:.2f}')
plt.xlim(-3, 3)
plt.legend()
plt.ylabel('Probability')
plt.xlabel(r'$ D - \hat{D}$ (mm)')
# Out:
# Text(0.5, 0, '$ D - \\hat{D}$ (mm)')

# %% [markdown]
# # Experimental D Calcs - IGNORE (See Coupon_Models-Grid Search)

# %%
from undt_ai.load import load_single
from pathlib import Path
from scipy.optimize import curve_fit
import numpy as np
import matplotlib.pyplot as plt
from undt_ai.tools import normal

fpath_s = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/synth_data_fft_vel.npz')
fpath_pkl = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/synth_data_params.pkl')
data = np.load(fpath_s)
df = pd.read_pickle(fpath_pkl)

fpath_e_coup = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/exp_coupons.npz')
t_coup, signal_coup, Dmin_coup, D_coup, rms_coup = load_single(fpath_e_coup, crop=0)

i06a = 'run38/Iteration491'
i06b = 'run33/Iteration192'
i09a = 'run38/Iteration489'
i09b = 'run23/s75'
i13a = 'run33/Iteration361'
i13b = 'run38/Iteration125'
runs = [i06a, i06b, i09a, i09b, i13a, i13b]

# %%
c_fe = 5670  #  (m/s) Approx. speed of sound in stainless steel
offset = 0.84 / 1e6
t_0 = offset

t_c_fft, t_c_exp = [], []
exp_idxs = []
for run in runs:
    
    plt.figure()
    D = df.loc[run]['D']
    exp_idx = np.argmax(D_coup == D)
    exp_idxs.append(exp_idx)
    idx = df.index.get_loc(run)
    #print(idx)

    
    for idx, (signal, i, l, t_c) in enumerate(zip([normal(data['signal'], start_idx=60), normal(signal_coup, start_idx=60)], 
                                             [idx, exp_idx], ['Synth (FFT)', 'Exp'], [t_c_fft, t_c_exp])):
        am = np.argmax(signal[i][crop:])
        peak_pos = t_coup[0][60:][am]
        t_c.append(peak_pos)
        
        plt.plot(1e6*t_coup[0], signal[i], label=l, c=f'C{idx}')
        plt.axvline(1e6*peak_pos, c=f'C{idx}')
        
        #plt.plot(1e6*t_coup[0], normal(signal_coup, start_idx=60)[exp_idx], label='Exp')
        plt.legend()
        plt.ylim(-1.5, 1.5)
        plt.xlim(0, 8)
        plt.xlabel(r'time ($\mu s$)')
        plt.ylabel('Normalised amplitude')
        
t_c_fft = np.array(t_c_fft)
t_c_exp = np.array(t_c_exp)

dt_max_fft = t_c_fft - t_0
dt_max_exp = t_c_exp - t_0

y_hat_D_max_fft = 1e3 * c_fe * dt_max_fft / 2
y_hat_D_max_exp = 1e3 * c_fe * dt_max_exp / 2

# %%
plt.plot(1e3*D_coup[exp_idxs], y_hat_D_max_fft, 'ro', label='FFT', mfc='w')
plt.plot(1e3*D_coup[exp_idxs], y_hat_D_max_exp, 'ko', label='Exp', mfc='w')
plt.plot([6, 15], [6, 15], 'k-')
plt.legend()
plt.grid()
rmse = np.mean((1e3*D_coup[exp_idxs] - y_hat_D_max_exp)**2)**0.5
print(rmse)
# Out:
# 0.32926056732830744

# %%
(1e3*D_coup - y_hat_D_max_exp)
# Out:
# array([[ 6.54362313],
#        [-0.70764538],
#        [ 3.33870681],
#        [ 0.47963842],
#        [-6.63194494],
#        [-3.97228151]])

# %%
1e3*D_coup, y_hat_D_max_exp
# Out:
# (array([[13.94723986],
#         [ 6.46841282],
#         [13.92814293],
#         [10.72773675],
#         [ 7.14331058],
#         [10.1443118 ]]),
#  array([[ 7.40361672],
#         [ 7.17605819],
#         [10.58943612],
#         [10.24809833],
#         [13.77525552],
#         [14.11659331]]))

# %%
c_fe = 5670  #  (m/s) Approx. speed of sound in stainless steel
offset = 0.84 / 1e6
t_0 = offset

t_c = []
for run in runs:
    #plt.figure()
    D = df.loc[run]['D']
    exp_idx = np.argmax(D_coup == D)
    idx = df.index.get_loc(run)
    #print(idx)
    sig = data['signal']
    crop = 60
    plt.plot(1e6*t_coup[0][crop:], signal_coup[idx][crop:])
    am = np.argmax(signal_coup[idx][crop:])
    peak_pos = t_coup[0][crop:][am]
    t_c.append(peak_pos)
    plt.axvline(1e6*peak_pos, color='k')
t_c = np.array(t_c)
dt_max_exp = t_c - t_0
y_hat_D_max_exp = 1e3 * c_fe * dt_max_exp / 2
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-71-4623a92ee5e0> in <module>
#      12     sig = data['signal']
#      13     crop = 60
# ---> 14     plt.plot(1e6*t_coup[0][crop:], signal_coup[idx][crop:])
#      15     am = np.argmax(signal_coup[idx][crop:])
#      16     peak_pos = t_coup[0][crop:][am]
#
# IndexError: index 5007 is out of bounds for axis 0 with size 6

# %%
for i in signal_coup:
    plt.plot(i)

# %%
c_fe = 5670  #  (m/s) Approx. speed of sound in stainless steel
offset = 0.84 / 1e6
t_0 = offset

t_c = []
for idx in range(6):
    crop = 60
    plt.plot(1e6*t_coup[0][crop:], signal_coup[idx][crop:])
    am = np.argmax(signal_coup[idx][crop:])
    peak_pos = t_coup[0][crop:][am]
    t_c.append(peak_pos)
    plt.axvline(1e6*peak_pos, color='k')
t_c = np.array(t_c)
dt_max_exp = t_c - t_0
y_hat_D_max_exp = 1e3 * c_fe * dt_max_exp / 2

# %%
plt.plot(D_coup, y_hat_D_max_exp, '.')
plt.plot([6, 15], [6, 15], 'k-')
rmse = np.mean(((D_coup - y_hat_D_max_exp)**2))**0.5
print(rmse)
# Out:
# 0.32926056732830744

# %%
#Compared Exp with Synthetic

# %%
import pandas as pd
fpath_s = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/synth_data.npz')
fpath_pkl = Path.home().joinpath('Dropbox/Projects/undt-ai/Data/synth_data_params.pkl')
data = np.load(fpath_s)
df = pd.read_pickle(fpath_pkl)

# t_coup, signal_coup, Dmin_coup, D_coup, rms_coup = load_single(fpath_e_coup, crop=0)
# signal_coup[:, :20] = 0
# D_coup = D_coup * 1000

# %%
exp_coupons = 
df
# Out:
#                            D      Dmin      Dmax  ...  Lambda_i     app_x     app_y
# run25/Iteration110  0.008534  0.006128  0.010403  ...   0.00030  0.006000  0.006000
# run25/Iteration141  0.010590  0.008977  0.012593  ...   0.00030  0.006000  0.006000
# run25/Iteration149  0.006368  0.004726  0.008286  ...   0.00030  0.006000  0.006000
# run25/Iteration200  0.011525  0.009540  0.013333  ...   0.00030  0.006000  0.006000
# run25/Iteration261  0.010855  0.008717  0.012855  ...   0.00030  0.006000  0.006000
# ...                      ...       ...       ...  ...       ...       ...       ...
# run24/s395          0.010179  0.008686  0.011532  ...   0.00075  0.005914  0.006352
# run24/s396          0.009235  0.008188  0.010057  ...   0.00075  0.003414  0.005852
# run24/s397          0.013547  0.012117  0.014907  ...   0.00075  0.005414  0.003852
# run24/s398          0.011413  0.010177  0.012587  ...   0.00075  0.004414  0.006852
# run24/s399          0.006763  0.005311  0.008157  ...   0.00075  0.006414  0.004852
#
# [12416 rows x 13 columns]

# %%
data['params']
# Out:
# array([[[0.00821742],
#         [0.00075   ],
#         [0.0003    ]],
#
#        [[0.01037056],
#         [0.00075   ],
#         [0.0003    ]],
#
#        [[0.00645663],
#         [0.00075   ],
#         [0.0003    ]],
#
#        ...,
#
#        [[0.01340039],
#         [0.0007    ],
#         [0.00075   ]],
#
#        [[0.01115039],
#         [0.0007    ],
#         [0.00075   ]],
#
#        [[0.00665039],
#         [0.0007    ],
#         [0.00075   ]]])
